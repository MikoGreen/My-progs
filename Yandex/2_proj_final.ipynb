# %% [markdown]
# # Исследование объявлений о продаже квартир
#
# В вашем распоряжении данные сервиса Яндекс.Недвижимость — архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктов за несколько лет. Нужно научиться определять рыночную стоимость объектов недвижимости. Ваша задача — установить параметры. Это позволит построить автоматизированную систему: она отследит аномалии и мошенническую деятельность.
#
# По каждой квартире на продажу доступны два вида данных. Первые вписаны пользователем, вторые — получены автоматически на основе картографических данных. Например, расстояние до центра, аэропорта, ближайшего парка и водоёма.

# %% [markdown]
# **Цель исследования:**
#
# 1. Определить рыночную стоимость объектов недвижимости.
# 2. Построить автоматизированную систему, которая отследит аномалии и мошенническую деятальность.
# 3. Установить, какие факторы влияют на ценообразование стоимости квартир.

# %% [markdown]
# **Ход исследования**
#
# Данные о недвижимости я получу из файла `'/datasets/real_estate_data.csv'`. О качестве данных ничего не известно. Поэтому перед тем, как приступать к целям исследования, понадобится обзор данных.
#
# Я проверю данные на ошибки и оценю их влияние на исследование. Затем, на этапе предобработки я поищу возможность исправить все ошибки данных, которые не приведут к искажению конечного результата. Далее, создам необходимые столбцы, и приступлю к проведению исследовательского анализа.
#
# Таким образом, моё исследование пройдёт в семь этапов:
#
# - Обзор данных.
# - Предобработка данных.
# - Расчеты и добавление результатов в таблицу.
# - Проведение анализа для Ленинградской области.
# - Проведение анализа для Санкт-Петербурга.
# - Различаются ли факторы, которые влияют на ценообразование стоимости квартир.
# - Написание общего вывода.

# %% [markdown]
# ### Откройте файл с данными и изучите общую информацию.

# %%
import pandas as pd
pd.set_option('display.max_columns', None)

import matplotlib as plt

# %%
import warnings #импортируем библиотеку

warnings.filterwarnings('ignore') # отключаем предупреждения

# %%
try:
    data = pd.read_csv('C:/Users/Home/Documents/Яндекс/need.csv', sep="\t")
except:
    data = pd.read_csv('/datasets/real_estate_data.csv', sep="\t")
data.head(10)
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0      108.00  2019-03-07T00:00:00      3
# 1             7   3350000.0       40.40  2018-12-04T00:00:00      1
# 2            10   5196000.0       56.00  2015-08-20T00:00:00      2
# 3             0  64900000.0      159.00  2015-07-24T00:00:00      3
# 4             2  10000000.0      100.00  2018-06-19T00:00:00      2
# 5            10   2890000.0       30.40  2018-09-10T00:00:00      1
# 6             6   3700000.0       37.30  2017-11-02T00:00:00      1
# 7             5   7915000.0       71.60  2019-04-18T00:00:00      2
# 8            20   2900000.0       33.16  2018-05-23T00:00:00      1
# 9            18   5400000.0       61.00  2017-02-26T00:00:00      3
#
#    ceiling_height  floors_total  living_area  floor is_apartment  studio  \
# 0            2.70          16.0        51.00      8          NaN   False
# 1             NaN          11.0        18.60      1          NaN   False
# 2             NaN           5.0        34.30      4          NaN   False
# 3             NaN          14.0          NaN      9          NaN   False
# 4            3.03          14.0        32.00     13          NaN   False
# 5             NaN          12.0        14.40      5          NaN   False
# 6             NaN          26.0        10.60      6          NaN   False
# 7             NaN          24.0          NaN     22          NaN   False
# 8             NaN          27.0        15.43     26          NaN   False
# 9            2.50           9.0        43.60      7          NaN   False
#
#    open_plan  kitchen_area  balcony              locality_name  \
# 0      False         25.00      NaN            Санкт-Петербург
# 1      False         11.00      2.0             посёлок Шушары
# 2      False          8.30      0.0            Санкт-Петербург
# 3      False           NaN      0.0            Санкт-Петербург
# 4      False         41.00      NaN            Санкт-Петербург
# 5      False          9.10      NaN  городской посёлок Янино-1
# 6      False         14.40      1.0          посёлок Парголово
# 7      False         18.90      2.0            Санкт-Петербург
# 8      False          8.81      NaN             посёлок Мурино
# 9      False          6.50      2.0            Санкт-Петербург
#
#    airports_nearest  cityCenters_nearest  parks_around3000  parks_nearest  \
# 0           18863.0              16028.0               1.0          482.0
# 1           12817.0              18603.0               0.0            NaN
# 2           21741.0              13933.0               1.0           90.0
# 3           28098.0               6800.0               2.0           84.0
# 4           31856.0               8098.0               2.0          112.0
# 5               NaN                  NaN               NaN            NaN
# 6           52996.0              19143.0               0.0            NaN
# 7           23982.0              11634.0               0.0            NaN
# 8               NaN                  NaN               NaN            NaN
# 9           50898.0              15008.0               0.0            NaN
#
#    ponds_around3000  ponds_nearest  days_exposition
# 0               2.0          755.0              NaN
# 1               0.0            NaN             81.0
# 2               2.0          574.0            558.0
# 3               3.0          234.0            424.0
# 4               1.0           48.0            121.0
# 5               NaN            NaN             55.0
# 6               0.0            NaN            155.0
# 7               0.0            NaN              NaN
# 8               NaN            NaN            189.0
# 9               0.0            NaN            289.0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          2775 non-null   object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               12180 non-null  float64
#  14  locality_name         23650 non-null  object
#  15  airports_nearest      18157 non-null  float64
#  16  cityCenters_nearest   18180 non-null  float64
#  17  parks_around3000      18181 non-null  float64
#  18  parks_nearest         8079 non-null   float64
#  19  ponds_around3000      18181 non-null  float64
#  20  ponds_nearest         9110 non-null   float64
#  21  days_exposition       20518 non-null  float64
# dtypes: bool(2), float64(14), int64(3), object(3)
# memory usage: 3.7+ MB

# %%
data.hist(figsize=(20,20));

# %% [markdown]
# Судя по графикам (по порядку):
#
# 1. Кажется странным 30 + фото, надо бы проверить, нет ли ошибки
#
# 2. В колонке last price не понятны значения около единицы по "Х"
#
# 3. Скорее всего есть взаимосвязь, между площадью квартиры, площадью кухни и количеством комнат - нужно проверить
#
# 4. Возможно вместе с ними и количество балконов, жилая площадь
#
# 5. К высоте потолков тоже вопросы - есть явный выброс непонятного характера, надо посмотреть что там.
#
# 6. Некоторые квартиры имеют жилую площадь, близкую к нулю - в наших реалиях выглядит странно, надо бы посмотреть с чем это может быть связано.
#
# 7. Некоторые колонки я бы переименовала, т.к. сочетания CamelCase и snake_case - тяжело воспринимаются. Конкретно - cityCenters_nearest, parks/pond_around3000
#
# 8. Ну и прежде всего хочется сделать сортировку по городам, потому как сравнивать объекты из разных городов - не самая лучшая как по мне идея.
#
# 9. Так же, я бы привела к другому типу данных несколько колонок - например - в колонке с датой можно убрать время вообще (так как нас интересует только сама дата и привести ее к виду to_datetime()

# %%
data.isna().sum()
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height           9195
# floors_total               86
# living_area              1903
# floor                       0
# is_apartment            20924
# studio                      0
# open_plan                   0
# kitchen_area             2278
# balcony                 11519
# locality_name              49
# airports_nearest         5542
# cityCenters_nearest      5519
# parks_around3000         5518
# parks_nearest           15620
# ponds_around3000         5518
# ponds_nearest           14589
# days_exposition          3181
# dtype: int64

# %% [markdown]
# Получается, что у нас очень много пропусков везде. Где то они означают "0", а где то - нехватку данных. Осталось понять где что.
#
# Возможно, там, где в столбцах булев тип данных - NaN = '0', а там где числовой - можно будет сгруппировать по тем данным, что у нас есть без пропусков, скажем, выделить характеристики объектов, и заполнить средними показателями по группе.
#
# Также, если смотреть логически, некоторые в некоторых колонках NaN все таки тоже может обозначать 0, тк, например, в доме может не быть балконов или объект может находиться в центре города => city_centers_nearest = 0
#
# Предполагаю, что пропуски в колонках про парки и пруды заполнить будет достаточно сложно, нужно будет обращаться к Яндекс.Картам, так что их думаю можно оставить как есть.
#
# Для начала, для удобства, я переименую некоторые столбцы:

# %% [markdown]
# ### Предобработка данных

# %%
data = data.rename(columns={'cityCenters_nearest':'city_centers_nearest',\
                            'parks_around3000':'parks_around_3000','ponds_around3000':'ponds_around_3000','studio':'is_studio'})
#data['first_day_exposition'] = pd.to_datetime(data['first_day_exposition'], format='%Y-%m-%d')

# %%
data
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 0                20  13000000.0      108.00  2019-03-07T00:00:00      3
# 1                 7   3350000.0       40.40  2018-12-04T00:00:00      1
# 2                10   5196000.0       56.00  2015-08-20T00:00:00      2
# 3                 0  64900000.0      159.00  2015-07-24T00:00:00      3
# 4                 2  10000000.0      100.00  2018-06-19T00:00:00      2
# ...             ...         ...         ...                  ...    ...
# 23694             9   9700000.0      133.81  2017-03-21T00:00:00      3
# 23695            14   3100000.0       59.00  2018-01-15T00:00:00      3
# 23696            18   2500000.0       56.70  2018-02-11T00:00:00      2
# 23697            13  11475000.0       76.75  2017-03-28T00:00:00      2
# 23698             4   1350000.0       32.30  2017-07-21T00:00:00      1
#
#        ceiling_height  floors_total  living_area  floor is_apartment  \
# 0                2.70          16.0         51.0      8          NaN
# 1                 NaN          11.0         18.6      1          NaN
# 2                 NaN           5.0         34.3      4          NaN
# 3                 NaN          14.0          NaN      9          NaN
# 4                3.03          14.0         32.0     13          NaN
# ...               ...           ...          ...    ...          ...
# 23694            3.70           5.0         73.3      3          NaN
# 23695             NaN           5.0         38.0      4          NaN
# 23696             NaN           3.0         29.7      1          NaN
# 23697            3.00          17.0          NaN     12          NaN
# 23698            2.50           5.0         12.3      1          NaN
#
#        is_studio  open_plan  kitchen_area  balcony        locality_name  \
# 0          False      False         25.00      NaN      Санкт-Петербург
# 1          False      False         11.00      2.0       посёлок Шушары
# 2          False      False          8.30      0.0      Санкт-Петербург
# 3          False      False           NaN      0.0      Санкт-Петербург
# 4          False      False         41.00      NaN      Санкт-Петербург
# ...          ...        ...           ...      ...                  ...
# 23694      False      False         13.83      NaN      Санкт-Петербург
# 23695      False      False          8.50      NaN                Тосно
# 23696      False      False           NaN      NaN     село Рождествено
# 23697      False      False         23.30      2.0      Санкт-Петербург
# 23698      False      False          9.00      NaN  поселок Новый Учхоз
#
#        airports_nearest  city_centers_nearest  parks_around_3000  \
# 0               18863.0               16028.0                1.0
# 1               12817.0               18603.0                0.0
# 2               21741.0               13933.0                1.0
# 3               28098.0                6800.0                2.0
# 4               31856.0                8098.0                2.0
# ...                 ...                   ...                ...
# 23694           24665.0                4232.0                1.0
# 23695               NaN                   NaN                NaN
# 23696               NaN                   NaN                NaN
# 23697           39140.0               10364.0                2.0
# 23698               NaN                   NaN                NaN
#
#        parks_nearest  ponds_around_3000  ponds_nearest  days_exposition
# 0              482.0                2.0          755.0              NaN
# 1                NaN                0.0            NaN             81.0
# 2               90.0                2.0          574.0            558.0
# 3               84.0                3.0          234.0            424.0
# 4              112.0                1.0           48.0            121.0
# ...              ...                ...            ...              ...
# 23694          796.0                3.0          381.0              NaN
# 23695            NaN                NaN            NaN             45.0
# 23696            NaN                NaN            NaN              NaN
# 23697          173.0                3.0          196.0            602.0
# 23698            NaN                NaN            NaN              NaN
#
# [23699 rows x 22 columns]

# %% [markdown]
# Также, у нас есть единственный столбец с текстовой информацией - название населённого пункта, проверим там на неявные дупликаты:

# %%
print(len(data['locality_name'].unique()))
data['locality_name'].unique()
# Out:
# 365
# array(['Санкт-Петербург', 'посёлок Шушары', 'городской посёлок Янино-1',
#        'посёлок Парголово', 'посёлок Мурино', 'Ломоносов', 'Сертолово',
#        'Петергоф', 'Пушкин', 'деревня Кудрово', 'Коммунар', 'Колпино',
#        'поселок городского типа Красный Бор', 'Гатчина', 'поселок Мурино',
#        'деревня Фёдоровское', 'Выборг', 'Кронштадт', 'Кировск',
#        'деревня Новое Девяткино', 'посёлок Металлострой',
#        'посёлок городского типа Лебяжье',
#        'посёлок городского типа Сиверский', 'поселок Молодцово',
#        'поселок городского типа Кузьмоловский',
#        'садовое товарищество Новая Ропша', 'Павловск',
#        'деревня Пикколово', 'Всеволожск', 'Волхов', 'Кингисепп',
#        'Приозерск', 'Сестрорецк', 'деревня Куттузи', 'посёлок Аннино',
#        'поселок городского типа Ефимовский', 'посёлок Плодовое',
#        'деревня Заклинье', 'поселок Торковичи', 'поселок Первомайское',
#        'Красное Село', 'посёлок Понтонный', 'Сясьстрой', 'деревня Старая',
#        'деревня Лесколово', 'посёлок Новый Свет', 'Сланцы',
#        'село Путилово', 'Ивангород', 'Мурино', 'Шлиссельбург',
#        'Никольское', 'Зеленогорск', 'Сосновый Бор', 'поселок Новый Свет',
#        'деревня Оржицы', 'деревня Кальтино', 'Кудрово',
#        'поселок Романовка', 'посёлок Бугры', 'поселок Бугры',
#        'поселок городского типа Рощино', 'Кириши', 'Луга', 'Волосово',
#        'Отрадное', 'село Павлово', 'поселок Оредеж', 'село Копорье',
#        'посёлок городского типа Красный Бор', 'посёлок Молодёжное',
#        'Тихвин', 'посёлок Победа', 'деревня Нурма',
#        'поселок городского типа Синявино', 'Тосно',
#        'посёлок городского типа Кузьмоловский', 'посёлок Стрельна',
#        'Бокситогорск', 'посёлок Александровская', 'деревня Лопухинка',
#        'Пикалёво', 'поселок Терволово',
#        'поселок городского типа Советский', 'Подпорожье',
#        'посёлок Петровское', 'посёлок городского типа Токсово',
#        'поселок Сельцо', 'посёлок городского типа Вырица',
#        'деревня Кипень', 'деревня Келози', 'деревня Вартемяги',
#        'посёлок Тельмана', 'поселок Севастьяново',
#        'городской поселок Большая Ижора', nan,
#        'городской посёлок Павлово', 'деревня Агалатово',
#        'посёлок Новогорелово', 'городской посёлок Лесогорский',
#        'деревня Лаголово', 'поселок Цвелодубово',
#        'поселок городского типа Рахья', 'поселок городского типа Вырица',
#        'деревня Белогорка', 'поселок Заводской',
#        'городской посёлок Новоселье', 'деревня Большие Колпаны',
#        'деревня Горбунки', 'деревня Батово', 'деревня Заневка',
#        'деревня Иссад', 'Приморск', 'городской посёлок Фёдоровское',
#        'деревня Мистолово', 'Новая Ладога', 'поселок Зимитицы',
#        'поселок Барышево', 'деревня Разметелево',
#        'поселок городского типа имени Свердлова', 'деревня Пеники',
#        'поселок Рябово', 'деревня Пудомяги', 'поселок станции Корнево',
#        'деревня Низино', 'деревня Бегуницы', 'посёлок Поляны',
#        'городской посёлок Мга', 'поселок Елизаветино',
#        'посёлок городского типа Кузнечное', 'деревня Колтуши',
#        'поселок Запорожское', 'посёлок городского типа Рощино',
#        'деревня Гостилицы', 'деревня Малое Карлино',
#        'посёлок Мичуринское', 'посёлок городского типа имени Морозова',
#        'посёлок Песочный', 'посёлок Сосново', 'деревня Аро',
#        'поселок Ильичёво', 'посёлок городского типа Тайцы',
#        'деревня Малое Верево', 'деревня Извара', 'поселок станции Вещево',
#        'село Паша', 'деревня Калитино',
#        'посёлок городского типа Ульяновка', 'деревня Чудской Бор',
#        'поселок городского типа Дубровка', 'деревня Мины',
#        'поселок Войсковицы', 'посёлок городского типа имени Свердлова',
#        'деревня Коркино', 'посёлок Ропша',
#        'поселок городского типа Приладожский', 'посёлок Щеглово',
#        'посёлок Гаврилово', 'Лодейное Поле', 'деревня Рабитицы',
#        'поселок городского типа Никольский', 'деревня Кузьмолово',
#        'деревня Малые Колпаны', 'поселок Тельмана',
#        'посёлок Петро-Славянка', 'городской посёлок Назия',
#        'посёлок Репино', 'посёлок Ильичёво', 'поселок Углово',
#        'поселок Старая Малукса', 'садовое товарищество Рахья',
#        'поселок Аннино', 'поселок Победа', 'деревня Меньково',
#        'деревня Старые Бегуницы', 'посёлок Сапёрный', 'поселок Семрино',
#        'поселок Гаврилово', 'поселок Глажево', 'поселок Кобринское',
#        'деревня Гарболово', 'деревня Юкки',
#        'поселок станции Приветнинское', 'деревня Мануйлово',
#        'деревня Пчева', 'поселок Поляны', 'поселок Цвылёво',
#        'поселок Мельниково', 'посёлок Пудость', 'посёлок Усть-Луга',
#        'Светогорск', 'Любань', 'поселок Селезнёво',
#        'поселок городского типа Рябово', 'Каменногорск', 'деревня Кривко',
#        'поселок Глебычево', 'деревня Парицы', 'поселок Жилпосёлок',
#        'посёлок городского типа Мга', 'городской поселок Янино-1',
#        'посёлок Войскорово', 'село Никольское', 'посёлок Терволово',
#        'поселок Стеклянный', 'посёлок городского типа Важины',
#        'посёлок Мыза-Ивановка', 'село Русско-Высоцкое',
#        'поселок городского типа Лебяжье',
#        'поселок городского типа Форносово', 'село Старая Ладога',
#        'поселок Житково', 'городской посёлок Виллози', 'деревня Лампово',
#        'деревня Шпаньково', 'деревня Лаврики', 'посёлок Сумино',
#        'посёлок Возрождение', 'деревня Старосиверская',
#        'посёлок Кикерино', 'поселок Возрождение',
#        'деревня Старое Хинколово', 'посёлок Пригородный',
#        'посёлок Торфяное', 'городской посёлок Будогощь',
#        'поселок Суходолье', 'поселок Красная Долина', 'деревня Хапо-Ое',
#        'поселок городского типа Дружная Горка', 'поселок Лисий Нос',
#        'деревня Яльгелево', 'посёлок Стеклянный', 'село Рождествено',
#        'деревня Старополье', 'посёлок Левашово', 'деревня Сяськелево',
#        'деревня Камышовка',
#        'садоводческое некоммерческое товарищество Лесная Поляна',
#        'деревня Хязельки', 'поселок Жилгородок',
#        'посёлок городского типа Павлово', 'деревня Ялгино',
#        'поселок Новый Учхоз', 'городской посёлок Рощино',
#        'поселок Гончарово', 'поселок Почап', 'посёлок Сапёрное',
#        'посёлок Платформа 69-й километр', 'поселок Каложицы',
#        'деревня Фалилеево', 'деревня Пельгора',
#        'поселок городского типа Лесогорский', 'деревня Торошковичи',
#        'посёлок Белоостров', 'посёлок Алексеевка', 'поселок Серебрянский',
#        'поселок Лукаши', 'поселок Петровское', 'деревня Щеглово',
#        'поселок Мичуринское', 'деревня Тарасово', 'поселок Кингисеппский',
#        'посёлок при железнодорожной станции Вещево', 'поселок Ушаки',
#        'деревня Котлы', 'деревня Сижно', 'деревня Торосово',
#        'посёлок Форт Красная Горка', 'поселок городского типа Токсово',
#        'деревня Новолисино', 'посёлок станции Громово', 'деревня Глинка',
#        'посёлок Мельниково', 'поселок городского типа Назия',
#        'деревня Старая Пустошь', 'поселок Коммунары', 'поселок Починок',
#        'посёлок городского типа Вознесенье', 'деревня Разбегаево',
#        'посёлок городского типа Рябово', 'поселок Гладкое',
#        'посёлок при железнодорожной станции Приветнинское',
#        'поселок Тёсово-4', 'посёлок Жилгородок', 'деревня Бор',
#        'посёлок Коробицыно', 'деревня Большая Вруда', 'деревня Курковицы',
#        'посёлок Лисий Нос', 'городской посёлок Советский',
#        'посёлок Кобралово', 'деревня Суоранда', 'поселок Кобралово',
#        'поселок городского типа Кондратьево',
#        'коттеджный поселок Счастье', 'поселок Любань', 'деревня Реброво',
#        'деревня Зимитицы', 'деревня Тойворово', 'поселок Семиозерье',
#        'поселок Лесное', 'поселок Совхозный', 'поселок Усть-Луга',
#        'посёлок Ленинское', 'посёлок Суйда',
#        'посёлок городского типа Форносово', 'деревня Нижние Осельки',
#        'посёлок станции Свирь', 'поселок Перово', 'Высоцк',
#        'поселок Гарболово', 'село Шум', 'поселок Котельский',
#        'поселок станции Лужайка', 'деревня Большая Пустомержа',
#        'поселок Красносельское', 'деревня Вахнова Кара', 'деревня Пижма',
#        'коттеджный поселок Кивеннапа Север', 'поселок Коробицыно',
#        'поселок Ромашки', 'посёлок Перово', 'деревня Каськово',
#        'деревня Куровицы', 'посёлок Плоское', 'поселок Сумино',
#        'поселок городского типа Большая Ижора', 'поселок Кирпичное',
#        'деревня Ям-Тесово', 'деревня Раздолье', 'деревня Терпилицы',
#        'посёлок Шугозеро', 'деревня Ваганово', 'поселок Пушное',
#        'садовое товарищество Садко', 'посёлок Усть-Ижора',
#        'деревня Выскатка', 'городской посёлок Свирьстрой',
#        'поселок Громово', 'деревня Кисельня', 'посёлок Старая Малукса',
#        'деревня Трубников Бор', 'поселок Калитино',
#        'посёлок Высокоключевой', 'садовое товарищество Приладожский',
#        'посёлок Пансионат Зелёный Бор', 'деревня Ненимяки',
#        'поселок Пансионат Зелёный Бор', 'деревня Снегирёвка',
#        'деревня Рапполово', 'деревня Пустынка', 'поселок Рабитицы',
#        'деревня Большой Сабск', 'деревня Русско', 'деревня Лупполово',
#        'деревня Большое Рейзино', 'деревня Малая Романовка',
#        'поселок Дружноселье', 'поселок Пчевжа', 'поселок Володарское',
#        'деревня Нижняя', 'коттеджный посёлок Лесное', 'деревня Тихковицы',
#        'деревня Борисова Грива', 'посёлок Дзержинского'], dtype=object)

# %% [markdown]
# Как и ожидалось, нужно заменить буквы и слова (возможно стоит привести все к нижнему регистру, но я не уверена):

# %%
data['locality_name'] = data['locality_name'].str.replace('ё', 'е', regex=False)
data['locality_name'] = data['locality_name'].str.replace('поселок городского типа', 'поселок', regex=False)

# %%
print(len(data['locality_name'].unique()))
data['locality_name'].unique()
# Out:
# 330
# array(['Санкт-Петербург', 'поселок Шушары', 'городской поселок Янино-1',
#        'поселок Парголово', 'поселок Мурино', 'Ломоносов', 'Сертолово',
#        'Петергоф', 'Пушкин', 'деревня Кудрово', 'Коммунар', 'Колпино',
#        'поселок Красный Бор', 'Гатчина', 'деревня Федоровское', 'Выборг',
#        'Кронштадт', 'Кировск', 'деревня Новое Девяткино',
#        'поселок Металлострой', 'поселок Лебяжье', 'поселок Сиверский',
#        'поселок Молодцово', 'поселок Кузьмоловский',
#        'садовое товарищество Новая Ропша', 'Павловск',
#        'деревня Пикколово', 'Всеволожск', 'Волхов', 'Кингисепп',
#        'Приозерск', 'Сестрорецк', 'деревня Куттузи', 'поселок Аннино',
#        'поселок Ефимовский', 'поселок Плодовое', 'деревня Заклинье',
#        'поселок Торковичи', 'поселок Первомайское', 'Красное Село',
#        'поселок Понтонный', 'Сясьстрой', 'деревня Старая',
#        'деревня Лесколово', 'поселок Новый Свет', 'Сланцы',
#        'село Путилово', 'Ивангород', 'Мурино', 'Шлиссельбург',
#        'Никольское', 'Зеленогорск', 'Сосновый Бор', 'деревня Оржицы',
#        'деревня Кальтино', 'Кудрово', 'поселок Романовка',
#        'поселок Бугры', 'поселок Рощино', 'Кириши', 'Луга', 'Волосово',
#        'Отрадное', 'село Павлово', 'поселок Оредеж', 'село Копорье',
#        'поселок Молодежное', 'Тихвин', 'поселок Победа', 'деревня Нурма',
#        'поселок Синявино', 'Тосно', 'поселок Стрельна', 'Бокситогорск',
#        'поселок Александровская', 'деревня Лопухинка', 'Пикалево',
#        'поселок Терволово', 'поселок Советский', 'Подпорожье',
#        'поселок Петровское', 'поселок Токсово', 'поселок Сельцо',
#        'поселок Вырица', 'деревня Кипень', 'деревня Келози',
#        'деревня Вартемяги', 'поселок Тельмана', 'поселок Севастьяново',
#        'городской поселок Большая Ижора', nan,
#        'городской поселок Павлово', 'деревня Агалатово',
#        'поселок Новогорелово', 'городской поселок Лесогорский',
#        'деревня Лаголово', 'поселок Цвелодубово', 'поселок Рахья',
#        'деревня Белогорка', 'поселок Заводской',
#        'городской поселок Новоселье', 'деревня Большие Колпаны',
#        'деревня Горбунки', 'деревня Батово', 'деревня Заневка',
#        'деревня Иссад', 'Приморск', 'городской поселок Федоровское',
#        'деревня Мистолово', 'Новая Ладога', 'поселок Зимитицы',
#        'поселок Барышево', 'деревня Разметелево',
#        'поселок имени Свердлова', 'деревня Пеники', 'поселок Рябово',
#        'деревня Пудомяги', 'поселок станции Корнево', 'деревня Низино',
#        'деревня Бегуницы', 'поселок Поляны', 'городской поселок Мга',
#        'поселок Елизаветино', 'поселок Кузнечное', 'деревня Колтуши',
#        'поселок Запорожское', 'деревня Гостилицы',
#        'деревня Малое Карлино', 'поселок Мичуринское',
#        'поселок имени Морозова', 'поселок Песочный', 'поселок Сосново',
#        'деревня Аро', 'поселок Ильичево', 'поселок Тайцы',
#        'деревня Малое Верево', 'деревня Извара', 'поселок станции Вещево',
#        'село Паша', 'деревня Калитино', 'поселок Ульяновка',
#        'деревня Чудской Бор', 'поселок Дубровка', 'деревня Мины',
#        'поселок Войсковицы', 'деревня Коркино', 'поселок Ропша',
#        'поселок Приладожский', 'поселок Щеглово', 'поселок Гаврилово',
#        'Лодейное Поле', 'деревня Рабитицы', 'поселок Никольский',
#        'деревня Кузьмолово', 'деревня Малые Колпаны',
#        'поселок Петро-Славянка', 'городской поселок Назия',
#        'поселок Репино', 'поселок Углово', 'поселок Старая Малукса',
#        'садовое товарищество Рахья', 'деревня Меньково',
#        'деревня Старые Бегуницы', 'поселок Саперный', 'поселок Семрино',
#        'поселок Глажево', 'поселок Кобринское', 'деревня Гарболово',
#        'деревня Юкки', 'поселок станции Приветнинское',
#        'деревня Мануйлово', 'деревня Пчева', 'поселок Цвылево',
#        'поселок Мельниково', 'поселок Пудость', 'поселок Усть-Луга',
#        'Светогорск', 'Любань', 'поселок Селезнево', 'Каменногорск',
#        'деревня Кривко', 'поселок Глебычево', 'деревня Парицы',
#        'поселок Жилпоселок', 'поселок Мга', 'поселок Войскорово',
#        'село Никольское', 'поселок Стеклянный', 'поселок Важины',
#        'поселок Мыза-Ивановка', 'село Русско-Высоцкое',
#        'поселок Форносово', 'село Старая Ладога', 'поселок Житково',
#        'городской поселок Виллози', 'деревня Лампово',
#        'деревня Шпаньково', 'деревня Лаврики', 'поселок Сумино',
#        'поселок Возрождение', 'деревня Старосиверская',
#        'поселок Кикерино', 'деревня Старое Хинколово',
#        'поселок Пригородный', 'поселок Торфяное',
#        'городской поселок Будогощь', 'поселок Суходолье',
#        'поселок Красная Долина', 'деревня Хапо-Ое',
#        'поселок Дружная Горка', 'поселок Лисий Нос', 'деревня Яльгелево',
#        'село Рождествено', 'деревня Старополье', 'поселок Левашово',
#        'деревня Сяськелево', 'деревня Камышовка',
#        'садоводческое некоммерческое товарищество Лесная Поляна',
#        'деревня Хязельки', 'поселок Жилгородок', 'поселок Павлово',
#        'деревня Ялгино', 'поселок Новый Учхоз',
#        'городской поселок Рощино', 'поселок Гончарово', 'поселок Почап',
#        'поселок Саперное', 'поселок Платформа 69-й километр',
#        'поселок Каложицы', 'деревня Фалилеево', 'деревня Пельгора',
#        'поселок Лесогорский', 'деревня Торошковичи', 'поселок Белоостров',
#        'поселок Алексеевка', 'поселок Серебрянский', 'поселок Лукаши',
#        'деревня Щеглово', 'деревня Тарасово', 'поселок Кингисеппский',
#        'поселок при железнодорожной станции Вещево', 'поселок Ушаки',
#        'деревня Котлы', 'деревня Сижно', 'деревня Торосово',
#        'поселок Форт Красная Горка', 'деревня Новолисино',
#        'поселок станции Громово', 'деревня Глинка', 'поселок Назия',
#        'деревня Старая Пустошь', 'поселок Коммунары', 'поселок Починок',
#        'поселок Вознесенье', 'деревня Разбегаево', 'поселок Гладкое',
#        'поселок при железнодорожной станции Приветнинское',
#        'поселок Тесово-4', 'деревня Бор', 'поселок Коробицыно',
#        'деревня Большая Вруда', 'деревня Курковицы',
#        'городской поселок Советский', 'поселок Кобралово',
#        'деревня Суоранда', 'поселок Кондратьево',
#        'коттеджный поселок Счастье', 'поселок Любань', 'деревня Реброво',
#        'деревня Зимитицы', 'деревня Тойворово', 'поселок Семиозерье',
#        'поселок Лесное', 'поселок Совхозный', 'поселок Ленинское',
#        'поселок Суйда', 'деревня Нижние Осельки', 'поселок станции Свирь',
#        'поселок Перово', 'Высоцк', 'поселок Гарболово', 'село Шум',
#        'поселок Котельский', 'поселок станции Лужайка',
#        'деревня Большая Пустомержа', 'поселок Красносельское',
#        'деревня Вахнова Кара', 'деревня Пижма',
#        'коттеджный поселок Кивеннапа Север', 'поселок Ромашки',
#        'деревня Каськово', 'деревня Куровицы', 'поселок Плоское',
#        'поселок Большая Ижора', 'поселок Кирпичное', 'деревня Ям-Тесово',
#        'деревня Раздолье', 'деревня Терпилицы', 'поселок Шугозеро',
#        'деревня Ваганово', 'поселок Пушное', 'садовое товарищество Садко',
#        'поселок Усть-Ижора', 'деревня Выскатка',
#        'городской поселок Свирьстрой', 'поселок Громово',
#        'деревня Кисельня', 'деревня Трубников Бор', 'поселок Калитино',
#        'поселок Высокоключевой', 'садовое товарищество Приладожский',
#        'поселок Пансионат Зеленый Бор', 'деревня Ненимяки',
#        'деревня Снегиревка', 'деревня Рапполово', 'деревня Пустынка',
#        'поселок Рабитицы', 'деревня Большой Сабск', 'деревня Русско',
#        'деревня Лупполово', 'деревня Большое Рейзино',
#        'деревня Малая Романовка', 'поселок Дружноселье', 'поселок Пчевжа',
#        'поселок Володарское', 'деревня Нижняя',
#        'коттеджный поселок Лесное', 'деревня Тихковицы',
#        'деревня Борисова Грива', 'поселок Дзержинского'], dtype=object)

# %% [markdown]
# Возникло предположение, что можно заменить пропущенные значения в living area и kitchen area исходя из средних по группировке по комнатам и общем метраже - скорее всего, при примерно одинаковых показателях того и другого, будет примерно одинаковое соотношение жилой площади и кухонной

# %%
pd.qcut(data['total_area'],4)
# Out:
# 0         (69.9, 900.0]
# 1          (40.0, 52.0]
# 2          (52.0, 69.9]
# 3         (69.9, 900.0]
# 4         (69.9, 900.0]
#               ...
# 23694     (69.9, 900.0]
# 23695      (52.0, 69.9]
# 23696      (52.0, 69.9]
# 23697     (69.9, 900.0]
# 23698    (11.999, 40.0]
# Name: total_area, Length: 23699, dtype: category
# Categories (4, interval[float64, right]): [(11.999, 40.0] < (40.0, 52.0] < (52.0, 69.9] < (69.9, 900.0]]

# %%
def area_category(t):
    if 11 < t < 40:
        return 'small'
    elif 40 < t < 52:
        return 'medium'
    elif 52 < t < 69.9:
        return 'big'
    else:
        return 'too_big'

# %%
data['area_category'] = data['total_area'].apply(area_category)

# %%
df1 = data.pivot_table(index='area_category', aggfunc='median', margins=True)\
[['rooms','total_area','kitchen_area','living_area']].copy()
df1['liv_per'] = (df1['living_area']/df1['total_area'])*100
df1['kit_per'] = (df1['kitchen_area']/df1['total_area'])*100
df1
# Out:
#                rooms  total_area  kitchen_area  living_area    liv_per  \
# area_category
# big                2        60.0         9.000         35.5  59.166667
# medium             2        45.0         8.000         27.3  60.666667
# small              1        34.0         8.100         17.1  50.294118
# too_big            3        84.4        12.415         50.0  59.241706
# All                2        60.0        10.000         35.0  58.333333
#
#                  kit_per
# area_category
# big            15.000000
# medium         17.777778
# small          23.823529
# too_big        14.709716
# All            16.666667

# %% [markdown]
# Разделив объекты по площади видно, что в среднем жилая площадь составляет 60% от всей, и около 17% на кухню - следовательно, думаю можно заполнить пропуски этими значениями

# %%
df2 = data[(data['living_area'].isna())|(data['kitchen_area'].isna())]\
[['total_area','living_area','kitchen_area']].copy()
df2['living_area'] = df2['living_area'].fillna(0.6*df2['total_area'])
df2['kitchen_area'] = df2['kitchen_area'].fillna(0.17*df2['total_area'])
df2
# Out:
#        total_area  living_area  kitchen_area
# 3          159.00        95.40        27.030
# 7           71.60        42.96        18.900
# 30          32.80        19.68         5.576
# 37          45.80        27.48         7.786
# 44          40.00        24.00         6.800
# ...           ...          ...           ...
# 23663       88.00        52.80        14.960
# 23670       45.60        27.36         7.752
# 23679       35.00        21.00         5.950
# 23696       56.70        29.70         9.639
# 23697       76.75        46.05        23.300
#
# [2717 rows x 3 columns]

# %%
data['living_area'] = data['living_area'].fillna(df2['living_area'])
data['kitchen_area'] = data['kitchen_area'].fillna(df2['kitchen_area'])
data
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 0                20  13000000.0      108.00  2019-03-07T00:00:00      3
# 1                 7   3350000.0       40.40  2018-12-04T00:00:00      1
# 2                10   5196000.0       56.00  2015-08-20T00:00:00      2
# 3                 0  64900000.0      159.00  2015-07-24T00:00:00      3
# 4                 2  10000000.0      100.00  2018-06-19T00:00:00      2
# ...             ...         ...         ...                  ...    ...
# 23694             9   9700000.0      133.81  2017-03-21T00:00:00      3
# 23695            14   3100000.0       59.00  2018-01-15T00:00:00      3
# 23696            18   2500000.0       56.70  2018-02-11T00:00:00      2
# 23697            13  11475000.0       76.75  2017-03-28T00:00:00      2
# 23698             4   1350000.0       32.30  2017-07-21T00:00:00      1
#
#        ceiling_height  floors_total  living_area  floor is_apartment  \
# 0                2.70          16.0        51.00      8          NaN
# 1                 NaN          11.0        18.60      1          NaN
# 2                 NaN           5.0        34.30      4          NaN
# 3                 NaN          14.0        95.40      9          NaN
# 4                3.03          14.0        32.00     13          NaN
# ...               ...           ...          ...    ...          ...
# 23694            3.70           5.0        73.30      3          NaN
# 23695             NaN           5.0        38.00      4          NaN
# 23696             NaN           3.0        29.70      1          NaN
# 23697            3.00          17.0        46.05     12          NaN
# 23698            2.50           5.0        12.30      1          NaN
#
#        is_studio  open_plan  kitchen_area  balcony        locality_name  \
# 0          False      False        25.000      NaN      Санкт-Петербург
# 1          False      False        11.000      2.0       поселок Шушары
# 2          False      False         8.300      0.0      Санкт-Петербург
# 3          False      False        27.030      0.0      Санкт-Петербург
# 4          False      False        41.000      NaN      Санкт-Петербург
# ...          ...        ...           ...      ...                  ...
# 23694      False      False        13.830      NaN      Санкт-Петербург
# 23695      False      False         8.500      NaN                Тосно
# 23696      False      False         9.639      NaN     село Рождествено
# 23697      False      False        23.300      2.0      Санкт-Петербург
# 23698      False      False         9.000      NaN  поселок Новый Учхоз
#
#        airports_nearest  city_centers_nearest  parks_around_3000  \
# 0               18863.0               16028.0                1.0
# 1               12817.0               18603.0                0.0
# 2               21741.0               13933.0                1.0
# 3               28098.0                6800.0                2.0
# 4               31856.0                8098.0                2.0
# ...                 ...                   ...                ...
# 23694           24665.0                4232.0                1.0
# 23695               NaN                   NaN                NaN
# 23696               NaN                   NaN                NaN
# 23697           39140.0               10364.0                2.0
# 23698               NaN                   NaN                NaN
#
#        parks_nearest  ponds_around_3000  ponds_nearest  days_exposition  \
# 0              482.0                2.0          755.0              NaN
# 1                NaN                0.0            NaN             81.0
# 2               90.0                2.0          574.0            558.0
# 3               84.0                3.0          234.0            424.0
# 4              112.0                1.0           48.0            121.0
# ...              ...                ...            ...              ...
# 23694          796.0                3.0          381.0              NaN
# 23695            NaN                NaN            NaN             45.0
# 23696            NaN                NaN            NaN              NaN
# 23697          173.0                3.0          196.0            602.0
# 23698            NaN                NaN            NaN              NaN
#
#       area_category
# 0           too_big
# 1            medium
# 2               big
# 3           too_big
# 4           too_big
# ...             ...
# 23694       too_big
# 23695           big
# 23696           big
# 23697       too_big
# 23698         small
#
# [23699 rows x 23 columns]

# %%
data.isna().sum()
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height           9195
# floors_total               86
# living_area                 0
# floor                       0
# is_apartment            20924
# is_studio                   0
# open_plan                   0
# kitchen_area                0
# balcony                 11519
# locality_name              49
# airports_nearest         5542
# city_centers_nearest     5519
# parks_around_3000        5518
# parks_nearest           15620
# ponds_around_3000        5518
# ponds_nearest           14589
# days_exposition          3181
# area_category               0
# dtype: int64

# %% [markdown]
# Таким образом мы избавились от пропусков в жилой площади

# %% [markdown]
# Возможно, есть какие либо закономерности у объектов с одинаковым количеством комнат. Также заметила, что у одних и тех же местоположений - одни и те же пропуски в airports и city centers. Есть вариант - заменить пропуски медианным значением по городу. Единственный нюанс - если по городу **вообще** не будет никаких данных - то получается, заполнять нужно нулём

# %%
for t in data['locality_name'].unique():
    try:
        data.loc[((data['locality_name']==t)&(data['airports_nearest'].isna())),'airports_nearest'] =\
        data.loc[(data['locality_name']==t),'airports_nearest'].median()
    except:
        data.loc[((data['locality_name']==t)&(data['airports_nearest'].isna())), 'airports_nearest'].fillna(0)
#data['airports_nearest'] = data['airports_nearest'].fillna(data['airports_nearest'].median())

import warnings #импортируем библиотеку
warnings.filterwarnings('ignore') # отключаем предупреждения

data
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 0                20  13000000.0      108.00  2019-03-07T00:00:00      3
# 1                 7   3350000.0       40.40  2018-12-04T00:00:00      1
# 2                10   5196000.0       56.00  2015-08-20T00:00:00      2
# 3                 0  64900000.0      159.00  2015-07-24T00:00:00      3
# 4                 2  10000000.0      100.00  2018-06-19T00:00:00      2
# ...             ...         ...         ...                  ...    ...
# 23694             9   9700000.0      133.81  2017-03-21T00:00:00      3
# 23695            14   3100000.0       59.00  2018-01-15T00:00:00      3
# 23696            18   2500000.0       56.70  2018-02-11T00:00:00      2
# 23697            13  11475000.0       76.75  2017-03-28T00:00:00      2
# 23698             4   1350000.0       32.30  2017-07-21T00:00:00      1
#
#        ceiling_height  floors_total  living_area  floor is_apartment  \
# 0                2.70          16.0        51.00      8          NaN
# 1                 NaN          11.0        18.60      1          NaN
# 2                 NaN           5.0        34.30      4          NaN
# 3                 NaN          14.0        95.40      9          NaN
# 4                3.03          14.0        32.00     13          NaN
# ...               ...           ...          ...    ...          ...
# 23694            3.70           5.0        73.30      3          NaN
# 23695             NaN           5.0        38.00      4          NaN
# 23696             NaN           3.0        29.70      1          NaN
# 23697            3.00          17.0        46.05     12          NaN
# 23698            2.50           5.0        12.30      1          NaN
#
#        is_studio  open_plan  kitchen_area  balcony        locality_name  \
# 0          False      False        25.000      NaN      Санкт-Петербург
# 1          False      False        11.000      2.0       поселок Шушары
# 2          False      False         8.300      0.0      Санкт-Петербург
# 3          False      False        27.030      0.0      Санкт-Петербург
# 4          False      False        41.000      NaN      Санкт-Петербург
# ...          ...        ...           ...      ...                  ...
# 23694      False      False        13.830      NaN      Санкт-Петербург
# 23695      False      False         8.500      NaN                Тосно
# 23696      False      False         9.639      NaN     село Рождествено
# 23697      False      False        23.300      2.0      Санкт-Петербург
# 23698      False      False         9.000      NaN  поселок Новый Учхоз
#
#        airports_nearest  city_centers_nearest  parks_around_3000  \
# 0               18863.0               16028.0                1.0
# 1               12817.0               18603.0                0.0
# 2               21741.0               13933.0                1.0
# 3               28098.0                6800.0                2.0
# 4               31856.0                8098.0                2.0
# ...                 ...                   ...                ...
# 23694           24665.0                4232.0                1.0
# 23695               NaN                   NaN                NaN
# 23696               NaN                   NaN                NaN
# 23697           39140.0               10364.0                2.0
# 23698               NaN                   NaN                NaN
#
#        parks_nearest  ponds_around_3000  ponds_nearest  days_exposition  \
# 0              482.0                2.0          755.0              NaN
# 1                NaN                0.0            NaN             81.0
# 2               90.0                2.0          574.0            558.0
# 3               84.0                3.0          234.0            424.0
# 4              112.0                1.0           48.0            121.0
# ...              ...                ...            ...              ...
# 23694          796.0                3.0          381.0              NaN
# 23695            NaN                NaN            NaN             45.0
# 23696            NaN                NaN            NaN              NaN
# 23697          173.0                3.0          196.0            602.0
# 23698            NaN                NaN            NaN              NaN
#
#       area_category
# 0           too_big
# 1            medium
# 2               big
# 3           too_big
# 4           too_big
# ...             ...
# 23694       too_big
# 23695           big
# 23696           big
# 23697       too_big
# 23698         small
#
# [23699 rows x 23 columns]

# %% [markdown]
# Не получается добавить нули, вместо пропусков в столбце с аэропортами, но я еще подумаю, как это можно сделать :(
#
# Ну и также приведем дату к божескому виду - время здесь везде 00:00, поэтому его можно отбросить, оставить только дату, а также для удобства переименуем 'studio' в 'is_studio'

# %%
data['first_day_exposition'] = pd.to_datetime(data['first_day_exposition'], format='%Y-%m-%d')
data
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 0                20  13000000.0      108.00           2019-03-07      3
# 1                 7   3350000.0       40.40           2018-12-04      1
# 2                10   5196000.0       56.00           2015-08-20      2
# 3                 0  64900000.0      159.00           2015-07-24      3
# 4                 2  10000000.0      100.00           2018-06-19      2
# ...             ...         ...         ...                  ...    ...
# 23694             9   9700000.0      133.81           2017-03-21      3
# 23695            14   3100000.0       59.00           2018-01-15      3
# 23696            18   2500000.0       56.70           2018-02-11      2
# 23697            13  11475000.0       76.75           2017-03-28      2
# 23698             4   1350000.0       32.30           2017-07-21      1
#
#        ceiling_height  floors_total  living_area  floor is_apartment  \
# 0                2.70          16.0        51.00      8          NaN
# 1                 NaN          11.0        18.60      1          NaN
# 2                 NaN           5.0        34.30      4          NaN
# 3                 NaN          14.0        95.40      9          NaN
# 4                3.03          14.0        32.00     13          NaN
# ...               ...           ...          ...    ...          ...
# 23694            3.70           5.0        73.30      3          NaN
# 23695             NaN           5.0        38.00      4          NaN
# 23696             NaN           3.0        29.70      1          NaN
# 23697            3.00          17.0        46.05     12          NaN
# 23698            2.50           5.0        12.30      1          NaN
#
#        is_studio  open_plan  kitchen_area  balcony        locality_name  \
# 0          False      False        25.000      NaN      Санкт-Петербург
# 1          False      False        11.000      2.0       поселок Шушары
# 2          False      False         8.300      0.0      Санкт-Петербург
# 3          False      False        27.030      0.0      Санкт-Петербург
# 4          False      False        41.000      NaN      Санкт-Петербург
# ...          ...        ...           ...      ...                  ...
# 23694      False      False        13.830      NaN      Санкт-Петербург
# 23695      False      False         8.500      NaN                Тосно
# 23696      False      False         9.639      NaN     село Рождествено
# 23697      False      False        23.300      2.0      Санкт-Петербург
# 23698      False      False         9.000      NaN  поселок Новый Учхоз
#
#        airports_nearest  city_centers_nearest  parks_around_3000  \
# 0               18863.0               16028.0                1.0
# 1               12817.0               18603.0                0.0
# 2               21741.0               13933.0                1.0
# 3               28098.0                6800.0                2.0
# 4               31856.0                8098.0                2.0
# ...                 ...                   ...                ...
# 23694           24665.0                4232.0                1.0
# 23695               NaN                   NaN                NaN
# 23696               NaN                   NaN                NaN
# 23697           39140.0               10364.0                2.0
# 23698               NaN                   NaN                NaN
#
#        parks_nearest  ponds_around_3000  ponds_nearest  days_exposition  \
# 0              482.0                2.0          755.0              NaN
# 1                NaN                0.0            NaN             81.0
# 2               90.0                2.0          574.0            558.0
# 3               84.0                3.0          234.0            424.0
# 4              112.0                1.0           48.0            121.0
# ...              ...                ...            ...              ...
# 23694          796.0                3.0          381.0              NaN
# 23695            NaN                NaN            NaN             45.0
# 23696            NaN                NaN            NaN              NaN
# 23697          173.0                3.0          196.0            602.0
# 23698            NaN                NaN            NaN              NaN
#
#       area_category
# 0           too_big
# 1            medium
# 2               big
# 3           too_big
# 4           too_big
# ...             ...
# 23694       too_big
# 23695           big
# 23696           big
# 23697       too_big
# 23698         small
#
# [23699 rows x 23 columns]

# %%
data.hist(figsize=(20,20));

# %%
data.boxplot(column='rooms');

# %%
data['rooms'].describe()
# Out:
# count    23699.000000
# mean         2.070636
# std          1.078405
# min          0.000000
# 25%          1.000000
# 50%          2.000000
# 75%          3.000000
# max         19.000000
# Name: rooms, dtype: float64

# %% [markdown]
# Объекты, где комнат > 6 - достаточно редкие явления, также как и живая площадь > 120 кв.м. и площадь кухни, так что я думаю, такие объекты можно исключить из выборки:

# %%
data.boxplot(column='total_area');

# %%
data['total_area'].describe()
# Out:
# count    23699.000000
# mean        60.348651
# std         35.654083
# min         12.000000
# 25%         40.000000
# 50%         52.000000
# 75%         69.900000
# max        900.000000
# Name: total_area, dtype: float64

# %% [markdown]
# Методом нехитрой математики, определив межквартильный диапазон и высчитав размер верхнего "уса" - посчитали, что граница значений находится на 112.5. Выше - выбросы по значениям, следовательно, все объекты, с площадью больше 112.5 квадратных метров - можно исключить из выборки

# %%
data = data.query('total_area <=112.5 & rooms <= 6')
data
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 0                20  13000000.0      108.00           2019-03-07      3
# 1                 7   3350000.0       40.40           2018-12-04      1
# 2                10   5196000.0       56.00           2015-08-20      2
# 4                 2  10000000.0      100.00           2018-06-19      2
# 5                10   2890000.0       30.40           2018-09-10      1
# ...             ...         ...         ...                  ...    ...
# 23693             9   4600000.0       62.40           2016-08-05      3
# 23695            14   3100000.0       59.00           2018-01-15      3
# 23696            18   2500000.0       56.70           2018-02-11      2
# 23697            13  11475000.0       76.75           2017-03-28      2
# 23698             4   1350000.0       32.30           2017-07-21      1
#
#        ceiling_height  floors_total  living_area  floor is_apartment  \
# 0                2.70          16.0        51.00      8          NaN
# 1                 NaN          11.0        18.60      1          NaN
# 2                 NaN           5.0        34.30      4          NaN
# 4                3.03          14.0        32.00     13          NaN
# 5                 NaN          12.0        14.40      5          NaN
# ...               ...           ...          ...    ...          ...
# 23693            2.60           9.0        40.00      8          NaN
# 23695             NaN           5.0        38.00      4          NaN
# 23696             NaN           3.0        29.70      1          NaN
# 23697            3.00          17.0        46.05     12          NaN
# 23698            2.50           5.0        12.30      1          NaN
#
#        is_studio  open_plan  kitchen_area  balcony              locality_name  \
# 0          False      False        25.000      NaN            Санкт-Петербург
# 1          False      False        11.000      2.0             поселок Шушары
# 2          False      False         8.300      0.0            Санкт-Петербург
# 4          False      False        41.000      NaN            Санкт-Петербург
# 5          False      False         9.100      NaN  городской поселок Янино-1
# ...          ...        ...           ...      ...                        ...
# 23693      False      False         8.000      0.0                   Петергоф
# 23695      False      False         8.500      NaN                      Тосно
# 23696      False      False         9.639      NaN           село Рождествено
# 23697      False      False        23.300      2.0            Санкт-Петербург
# 23698      False      False         9.000      NaN        поселок Новый Учхоз
#
#        airports_nearest  city_centers_nearest  parks_around_3000  \
# 0               18863.0               16028.0                1.0
# 1               12817.0               18603.0                0.0
# 2               21741.0               13933.0                1.0
# 4               31856.0                8098.0                2.0
# 5                   NaN                   NaN                NaN
# ...                 ...                   ...                ...
# 23693           45602.0               34104.0                1.0
# 23695               NaN                   NaN                NaN
# 23696               NaN                   NaN                NaN
# 23697           39140.0               10364.0                2.0
# 23698               NaN                   NaN                NaN
#
#        parks_nearest  ponds_around_3000  ponds_nearest  days_exposition  \
# 0              482.0                2.0          755.0              NaN
# 1                NaN                0.0            NaN             81.0
# 2               90.0                2.0          574.0            558.0
# 4              112.0                1.0           48.0            121.0
# 5                NaN                NaN            NaN             55.0
# ...              ...                ...            ...              ...
# 23693          352.0                1.0          675.0            239.0
# 23695            NaN                NaN            NaN             45.0
# 23696            NaN                NaN            NaN              NaN
# 23697          173.0                3.0          196.0            602.0
# 23698            NaN                NaN            NaN              NaN
#
#       area_category
# 0           too_big
# 1            medium
# 2               big
# 4           too_big
# 5             small
# ...             ...
# 23693           big
# 23695           big
# 23696           big
# 23697       too_big
# 23698         small
#
# [22385 rows x 23 columns]

# %%
data.hist(figsize=(20,20));

# %%
data['balcony'] = data['balcony'].fillna(0)

# %%
data['balcony'] = data['balcony'].astype(int)

# %%
data
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 0                20  13000000.0      108.00           2019-03-07      3
# 1                 7   3350000.0       40.40           2018-12-04      1
# 2                10   5196000.0       56.00           2015-08-20      2
# 4                 2  10000000.0      100.00           2018-06-19      2
# 5                10   2890000.0       30.40           2018-09-10      1
# ...             ...         ...         ...                  ...    ...
# 23693             9   4600000.0       62.40           2016-08-05      3
# 23695            14   3100000.0       59.00           2018-01-15      3
# 23696            18   2500000.0       56.70           2018-02-11      2
# 23697            13  11475000.0       76.75           2017-03-28      2
# 23698             4   1350000.0       32.30           2017-07-21      1
#
#        ceiling_height  floors_total  living_area  floor is_apartment  \
# 0                2.70          16.0        51.00      8          NaN
# 1                 NaN          11.0        18.60      1          NaN
# 2                 NaN           5.0        34.30      4          NaN
# 4                3.03          14.0        32.00     13          NaN
# 5                 NaN          12.0        14.40      5          NaN
# ...               ...           ...          ...    ...          ...
# 23693            2.60           9.0        40.00      8          NaN
# 23695             NaN           5.0        38.00      4          NaN
# 23696             NaN           3.0        29.70      1          NaN
# 23697            3.00          17.0        46.05     12          NaN
# 23698            2.50           5.0        12.30      1          NaN
#
#        is_studio  open_plan  kitchen_area  balcony              locality_name  \
# 0          False      False        25.000        0            Санкт-Петербург
# 1          False      False        11.000        2             поселок Шушары
# 2          False      False         8.300        0            Санкт-Петербург
# 4          False      False        41.000        0            Санкт-Петербург
# 5          False      False         9.100        0  городской поселок Янино-1
# ...          ...        ...           ...      ...                        ...
# 23693      False      False         8.000        0                   Петергоф
# 23695      False      False         8.500        0                      Тосно
# 23696      False      False         9.639        0           село Рождествено
# 23697      False      False        23.300        2            Санкт-Петербург
# 23698      False      False         9.000        0        поселок Новый Учхоз
#
#        airports_nearest  city_centers_nearest  parks_around_3000  \
# 0               18863.0               16028.0                1.0
# 1               12817.0               18603.0                0.0
# 2               21741.0               13933.0                1.0
# 4               31856.0                8098.0                2.0
# 5                   NaN                   NaN                NaN
# ...                 ...                   ...                ...
# 23693           45602.0               34104.0                1.0
# 23695               NaN                   NaN                NaN
# 23696               NaN                   NaN                NaN
# 23697           39140.0               10364.0                2.0
# 23698               NaN                   NaN                NaN
#
#        parks_nearest  ponds_around_3000  ponds_nearest  days_exposition  \
# 0              482.0                2.0          755.0              NaN
# 1                NaN                0.0            NaN             81.0
# 2               90.0                2.0          574.0            558.0
# 4              112.0                1.0           48.0            121.0
# 5                NaN                NaN            NaN             55.0
# ...              ...                ...            ...              ...
# 23693          352.0                1.0          675.0            239.0
# 23695            NaN                NaN            NaN             45.0
# 23696            NaN                NaN            NaN              NaN
# 23697          173.0                3.0          196.0            602.0
# 23698            NaN                NaN            NaN              NaN
#
#       area_category
# 0           too_big
# 1            medium
# 2               big
# 4           too_big
# 5             small
# ...             ...
# 23693           big
# 23695           big
# 23696           big
# 23697       too_big
# 23698         small
#
# [22385 rows x 23 columns]

# %%
data['is_apartment'] = data['is_apartment'].fillna(False)

# %% [markdown]
# Так как пропусков в *floors_total* < 5%, то чтобы сэкономить время, уберем строки с пропусками:

# %%
data = data[data['floors_total'].notna()]

# %% [markdown]
# Балконы не могут быть половинчатыми, и их стоит привести к типу *int*, также как и *floors_total*, а *is_apartment* к типу *bool*

# %%
data = data.astype({'balcony': int, 'floors_total': int, 'is_apartment':bool})

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22304 entries, 0 to 23698
# Data columns (total 23 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          22304 non-null  int64
#  1   last_price            22304 non-null  float64
#  2   total_area            22304 non-null  float64
#  3   first_day_exposition  22304 non-null  datetime64[ns]
#  4   rooms                 22304 non-null  int64
#  5   ceiling_height        13600 non-null  float64
#  6   floors_total          22304 non-null  int32
#  7   living_area           22304 non-null  float64
#  8   floor                 22304 non-null  int64
#  9   is_apartment          22304 non-null  bool
#  10  is_studio             22304 non-null  bool
#  11  open_plan             22304 non-null  bool
#  12  kitchen_area          22304 non-null  float64
#  13  balcony               22304 non-null  int32
#  14  locality_name         22259 non-null  object
#  15  airports_nearest      17473 non-null  float64
#  16  city_centers_nearest  16844 non-null  float64
#  17  parks_around_3000     16845 non-null  float64
#  18  parks_nearest         7209 non-null   float64
#  19  ponds_around_3000     16845 non-null  float64
#  20  ponds_nearest         8230 non-null   float64
#  21  days_exposition       19463 non-null  float64
#  22  area_category         22304 non-null  object
# dtypes: bool(3), datetime64[ns](1), float64(12), int32(2), int64(3), object(2)
# memory usage: 3.5+ MB

# %%
data.isna().sum()
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height           8704
# floors_total                0
# living_area                 0
# floor                       0
# is_apartment                0
# is_studio                   0
# open_plan                   0
# kitchen_area                0
# balcony                     0
# locality_name              45
# airports_nearest         4831
# city_centers_nearest     5460
# parks_around_3000        5459
# parks_nearest           15095
# ponds_around_3000        5459
# ponds_nearest           14074
# days_exposition          2841
# area_category               0
# dtype: int64

# %% [markdown]
# Строки с пропусками в *locality_name*  тоже стоит убрать, потому что это будет мешать в дальнейшем анализе:

# %%
data = data[data['locality_name'].notna()]
data
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 0                20  13000000.0      108.00           2019-03-07      3
# 1                 7   3350000.0       40.40           2018-12-04      1
# 2                10   5196000.0       56.00           2015-08-20      2
# 4                 2  10000000.0      100.00           2018-06-19      2
# 5                10   2890000.0       30.40           2018-09-10      1
# ...             ...         ...         ...                  ...    ...
# 23693             9   4600000.0       62.40           2016-08-05      3
# 23695            14   3100000.0       59.00           2018-01-15      3
# 23696            18   2500000.0       56.70           2018-02-11      2
# 23697            13  11475000.0       76.75           2017-03-28      2
# 23698             4   1350000.0       32.30           2017-07-21      1
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  \
# 0                2.70            16        51.00      8         False
# 1                 NaN            11        18.60      1         False
# 2                 NaN             5        34.30      4         False
# 4                3.03            14        32.00     13         False
# 5                 NaN            12        14.40      5         False
# ...               ...           ...          ...    ...           ...
# 23693            2.60             9        40.00      8         False
# 23695             NaN             5        38.00      4         False
# 23696             NaN             3        29.70      1         False
# 23697            3.00            17        46.05     12         False
# 23698            2.50             5        12.30      1         False
#
#        is_studio  open_plan  kitchen_area  balcony              locality_name  \
# 0          False      False        25.000        0            Санкт-Петербург
# 1          False      False        11.000        2             поселок Шушары
# 2          False      False         8.300        0            Санкт-Петербург
# 4          False      False        41.000        0            Санкт-Петербург
# 5          False      False         9.100        0  городской поселок Янино-1
# ...          ...        ...           ...      ...                        ...
# 23693      False      False         8.000        0                   Петергоф
# 23695      False      False         8.500        0                      Тосно
# 23696      False      False         9.639        0           село Рождествено
# 23697      False      False        23.300        2            Санкт-Петербург
# 23698      False      False         9.000        0        поселок Новый Учхоз
#
#        airports_nearest  city_centers_nearest  parks_around_3000  \
# 0               18863.0               16028.0                1.0
# 1               12817.0               18603.0                0.0
# 2               21741.0               13933.0                1.0
# 4               31856.0                8098.0                2.0
# 5                   NaN                   NaN                NaN
# ...                 ...                   ...                ...
# 23693           45602.0               34104.0                1.0
# 23695               NaN                   NaN                NaN
# 23696               NaN                   NaN                NaN
# 23697           39140.0               10364.0                2.0
# 23698               NaN                   NaN                NaN
#
#        parks_nearest  ponds_around_3000  ponds_nearest  days_exposition  \
# 0              482.0                2.0          755.0              NaN
# 1                NaN                0.0            NaN             81.0
# 2               90.0                2.0          574.0            558.0
# 4              112.0                1.0           48.0            121.0
# 5                NaN                NaN            NaN             55.0
# ...              ...                ...            ...              ...
# 23693          352.0                1.0          675.0            239.0
# 23695            NaN                NaN            NaN             45.0
# 23696            NaN                NaN            NaN              NaN
# 23697          173.0                3.0          196.0            602.0
# 23698            NaN                NaN            NaN              NaN
#
#       area_category
# 0           too_big
# 1            medium
# 2               big
# 4           too_big
# 5             small
# ...             ...
# 23693           big
# 23695           big
# 23696           big
# 23697       too_big
# 23698         small
#
# [22259 rows x 23 columns]

# %%
data['ceiling_height'].unique()
# Out:
# array([  2.7 ,    nan,   3.03,   2.5 ,   2.67,   2.56,   3.05,   2.75,
#          2.6 ,   2.9 ,   2.8 ,   2.55,   3.  ,   2.65,   2.61,   3.2 ,
#          3.25,   3.45,   2.77,   2.64,   2.57,   4.15,   4.  ,   2.47,
#          2.73,   2.84,   3.1 ,   2.34,   3.4 ,   3.06,   2.72,   2.54,
#          2.51,   2.78,   2.76,  25.  ,   2.58,   3.7 ,   2.52,   3.5 ,
#          2.87,   2.66,   2.59,   2.  ,   2.85,   3.3 ,   2.45,   2.92,
#          3.13,   3.8 ,   3.15,   3.55,   3.62,   3.12,   2.53,   2.96,
#          2.46,   2.74,   5.  ,   2.79,   2.95,   4.06,   2.94,   3.54,
#          3.53,   2.83,   2.4 ,   3.38,   3.01,   3.65,   2.71,   3.35,
#          2.3 ,   2.48,   2.62,   3.57,   2.82,   3.98,   2.63,   3.83,
#          3.75,   2.88,   3.66,   4.19,   3.24,   4.8 ,   4.5 ,   4.2 ,
#         32.  ,   3.68,   3.07,   3.37,   3.09,   8.  ,   3.16,   3.6 ,
#          3.34,   2.81,   3.44,   2.97,   4.37,   2.68,   3.9 ,   3.27,
#         27.  ,   4.1 ,   3.95,   3.46,  24.  ,   3.47,   3.33,   3.63,
#          3.14,   3.32,   3.52,  26.  ,   1.2 ,   3.18,   8.3 ,   2.93,
#          2.98,   3.36,   2.86,   3.08,   3.17,   3.11,   3.67,   3.28,
#          3.04,   3.26,   3.84,   3.23,   3.02,   3.21,   4.3 ,   3.39,
#          2.69,   3.22,   5.3 ,   3.56,   2.2 ,   3.85,   3.93,   3.42,
#          2.99,  14.  ,   3.78,   3.31,   3.88,   1.75,   4.25,  20.  ,
#          2.25,   4.7 ,  22.6 ,   2.89,   5.8 ,  27.5 ,   2.49,   2.91,
#          3.48,  10.3 ,   1.  ,   3.49, 100.  ,   3.59])

# %%
data[data['ceiling_height']>10]
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 355              17   3600000.0        55.2           2018-07-12      2
# 3148             14   2900000.0        75.0           2018-11-12      3
# 4643              0   4300000.0        45.0           2018-02-01      2
# 4876              7   3000000.0        25.0           2017-09-27      0
# 5076              0   3850000.0        30.5           2018-10-03      1
# 5246              0   2500000.0        54.0           2017-10-13      2
# 5669              4   4400000.0        50.0           2017-08-08      2
# 5807             17   8150000.0        80.0           2019-01-09      2
# 6246              6   3300000.0        44.4           2019-03-25      2
# 9379              5   3950000.0        42.0           2017-03-26      3
# 10773             8   3800000.0        58.0           2017-10-13      2
# 11285             0   1950000.0        37.0           2019-03-20      1
# 14382             9   1700000.0        35.0           2015-12-04      1
# 15061            19   5600000.0        56.4           2018-05-11      2
# 17496            15   6700000.0        92.9           2019-02-19      3
# 17857             1   3900000.0        56.0           2017-12-22      3
# 18545             6   3750000.0        43.0           2019-03-18      2
# 20478            11   8000000.0        45.0           2017-07-18      1
# 20507            12   5950000.0        60.0           2018-02-19      2
# 21377            19   4900000.0        42.0           2017-04-18      1
# 21824            20   2450000.0        44.0           2019-02-12      2
# 22309            20   5300000.0        45.0           2017-09-30      1
# 22336            19   9999000.0        92.4           2019-04-05      2
# 22869             0  15000000.0        25.0           2018-07-25      1
# 22938            14   4000000.0        98.0           2018-03-15      4
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  \
# 355              25.0             5         32.0      2         False
# 3148             32.0             3         53.0      2         False
# 4643             25.0             9         30.0      2         False
# 4876             27.0            25         17.0     17         False
# 5076             24.0             5         19.5      1          True
# 5246             27.0             5         30.0      3         False
# 5669             26.0             9         21.3      3         False
# 5807             27.0            36         41.0     13         False
# 6246             25.0             5         31.3      5         False
# 9379             25.0             5         30.0      2         False
# 10773            27.0            10         30.1      3         False
# 11285            25.0             5         17.0      4         False
# 14382            25.0             5         20.0      2         False
# 15061            14.0            14         32.4      5         False
# 17496            20.0            17         53.2     14         False
# 17857            27.0             5         33.0      4         False
# 18545            25.0             5         29.0      3         False
# 20478            27.0             4         22.0      2         False
# 20507            22.6            14         35.0     11         False
# 21377            27.5            24         37.7     19         False
# 21824            27.0             2         38.0      2         False
# 22309            10.3            16         15.5     15         False
# 22336            32.0             6         55.5      5         False
# 22869           100.0             5         14.0      5          True
# 22938            27.0             2         73.0      2          True
#
#        is_studio  open_plan  kitchen_area  balcony  \
# 355        False      False         9.384        2
# 3148       False      False         8.000        0
# 4643       False      False         7.000        1
# 4876       False       True         4.250        2
# 5076       False      False         5.500        0
# 5246       False      False         9.000        2
# 5669       False      False         7.000        2
# 5807       False      False        12.000        5
# 6246       False      False         5.700        0
# 9379       False      False         5.200        0
# 10773      False      False         8.100        2
# 11285      False      False         9.000        2
# 14382      False      False         8.000        1
# 15061      False      False         9.100        2
# 17496      False      False        12.000        5
# 17857      False      False         9.520        0
# 18545      False      False         7.310        0
# 20478      False      False        10.000        1
# 20507      False      False        13.000        1
# 21377      False      False        11.000        2
# 21824      False      False         8.600        2
# 22309      False      False         7.650        0
# 22336      False      False        16.500        4
# 22869      False      False        11.000        5
# 22938      False      False         9.000        1
#
#                          locality_name  airports_nearest  \
# 355                            Гатчина               NaN
# 3148                            Волхов               NaN
# 4643                   Санкт-Петербург           12016.0
# 4876                    поселок Мурино           51553.0
# 5076                   Санкт-Петербург           29686.0
# 5246                      деревня Мины               NaN
# 5669                   Санкт-Петербург           28981.0
# 5807                   Санкт-Петербург           18732.0
# 6246                         Кронштадт           68923.0
# 9379                   Санкт-Петербург           11647.0
# 10773                   поселок Мурино           51553.0
# 11285                             Луга               NaN
# 14382               поселок Новый Свет               NaN
# 15061                  Санкт-Петербург           14814.0
# 17496                  Санкт-Петербург           16295.0
# 17857                  Санкт-Петербург           41030.0
# 18545                  Санкт-Петербург           27054.0
# 20478                  Санкт-Петербург           18975.0
# 20507                  Санкт-Петербург           27028.0
# 21377                  Санкт-Петербург           42742.0
# 21824  городской поселок Большая Ижора               NaN
# 22309                  Санкт-Петербург           36353.0
# 22336                  Санкт-Петербург           18838.0
# 22869                  Санкт-Петербург           34963.0
# 22938                   деревня Нижняя               NaN
#
#        city_centers_nearest  parks_around_3000  parks_nearest  \
# 355                     NaN                NaN            NaN
# 3148                    NaN                NaN            NaN
# 4643                13256.0                1.0          658.0
# 4876                    NaN                NaN            NaN
# 5076                 8389.0                3.0          397.0
# 5246                    NaN                NaN            NaN
# 5669                10912.0                1.0          305.0
# 5807                20444.0                0.0            NaN
# 6246                50649.0                1.0          417.0
# 9379                13581.0                0.0            NaN
# 10773                   NaN                NaN            NaN
# 11285                   NaN                NaN            NaN
# 14382                   NaN                NaN            NaN
# 15061               13610.0                0.0            NaN
# 17496               15092.0                1.0          967.0
# 17857               15543.0                0.0            NaN
# 18545                8033.0                1.0          540.0
# 20478                3246.0                0.0            NaN
# 20507               12570.0                0.0            NaN
# 21377                9760.0                0.0            NaN
# 21824                   NaN                NaN            NaN
# 22309               11936.0                2.0          440.0
# 22336                3506.0                0.0            NaN
# 22869                8283.0                1.0          223.0
# 22938                   NaN                NaN            NaN
#
#        ponds_around_3000  ponds_nearest  days_exposition area_category
# 355                  NaN            NaN            259.0           big
# 3148                 NaN            NaN              NaN       too_big
# 4643                 1.0          331.0            181.0        medium
# 4876                 NaN            NaN             28.0         small
# 5076                 1.0          578.0              7.0         small
# 5246                 NaN            NaN            540.0           big
# 5669                 0.0            NaN            267.0        medium
# 5807                 3.0           80.0             38.0       too_big
# 6246                 2.0           73.0              NaN        medium
# 9379                 0.0            NaN              NaN        medium
# 10773                NaN            NaN             71.0           big
# 11285                NaN            NaN             18.0         small
# 14382                NaN            NaN            206.0         small
# 15061                0.0            NaN            315.0           big
# 17496                0.0            NaN              NaN       too_big
# 17857                0.0            NaN             73.0           big
# 18545                0.0            NaN             12.0        medium
# 20478                3.0          449.0            429.0        medium
# 20507                0.0            NaN             40.0           big
# 21377                0.0            NaN             61.0        medium
# 21824                NaN            NaN              NaN        medium
# 22309                2.0          450.0            136.0        medium
# 22336                3.0          511.0              NaN       too_big
# 22869                3.0           30.0             19.0         small
# 22938                NaN            NaN             27.0       too_big

# %%
data['ceiling_height'] = data['ceiling_height'].apply(lambda x: x/10 if x > 10 else x)

# %%
data['ceiling_height'].unique()
# Out:
# array([ 2.7 ,   nan,  3.03,  2.5 ,  2.67,  2.56,  3.05,  2.75,  2.6 ,
#         2.9 ,  2.8 ,  2.55,  3.  ,  2.65,  2.61,  3.2 ,  3.25,  3.45,
#         2.77,  2.64,  2.57,  4.15,  4.  ,  2.47,  2.73,  2.84,  3.1 ,
#         2.34,  3.4 ,  3.06,  2.72,  2.54,  2.51,  2.78,  2.76,  2.58,
#         3.7 ,  2.52,  3.5 ,  2.87,  2.66,  2.59,  2.  ,  2.85,  3.3 ,
#         2.45,  2.92,  3.13,  3.8 ,  3.15,  3.55,  3.62,  3.12,  2.53,
#         2.96,  2.46,  2.74,  5.  ,  2.79,  2.95,  4.06,  2.94,  3.54,
#         3.53,  2.83,  2.4 ,  3.38,  3.01,  3.65,  2.71,  3.35,  2.3 ,
#         2.48,  2.62,  3.57,  2.82,  3.98,  2.63,  3.83,  3.75,  2.88,
#         3.66,  4.19,  3.24,  4.8 ,  4.5 ,  4.2 ,  3.68,  3.07,  3.37,
#         3.09,  8.  ,  3.16,  3.6 ,  3.34,  2.81,  3.44,  2.97,  4.37,
#         2.68,  3.9 ,  3.27,  4.1 ,  3.95,  3.46,  3.47,  3.33,  3.63,
#         3.14,  3.32,  3.52,  1.2 ,  3.18,  8.3 ,  2.93,  2.98,  3.36,
#         2.86,  3.08,  3.17,  3.11,  3.67,  3.28,  3.04,  3.26,  3.84,
#         3.23,  3.02,  3.21,  4.3 ,  3.39,  2.69,  3.22,  5.3 ,  3.56,
#         2.2 ,  3.85,  3.93,  3.42,  2.99,  1.4 ,  3.78,  3.31,  3.88,
#         1.75,  4.25,  2.25,  4.7 ,  2.26,  2.89,  5.8 ,  2.49,  2.91,
#         3.48,  1.03,  1.  ,  3.49, 10.  ,  3.59])

# %%
data.isna().sum()
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height           8672
# floors_total                0
# living_area                 0
# floor                       0
# is_apartment                0
# is_studio                   0
# open_plan                   0
# kitchen_area                0
# balcony                     0
# locality_name               0
# airports_nearest         4823
# city_centers_nearest     5452
# parks_around_3000        5451
# parks_nearest           15063
# ponds_around_3000        5451
# ponds_nearest           14053
# days_exposition          2840
# area_category               0
# dtype: int64

# %% [markdown]
# Пропуски в высоте потолков заполнить не получится, т.к. у разных зданий и разных комнат будут разные потолки, необходимо понимать тип здания (допустим, Хрущевка или Сталинка и т.п.) и заполнять уже на основе этих данных. Но так как этих данных у нас нет, то пропуски в этих колонках я оставлю нетронутыми.

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data['airports_nearest'] = data['airports_nearest'].fillna(0)
data
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 0                20  13000000.0      108.00           2019-03-07      3
# 1                 7   3350000.0       40.40           2018-12-04      1
# 2                10   5196000.0       56.00           2015-08-20      2
# 4                 2  10000000.0      100.00           2018-06-19      2
# 5                10   2890000.0       30.40           2018-09-10      1
# ...             ...         ...         ...                  ...    ...
# 23693             9   4600000.0       62.40           2016-08-05      3
# 23695            14   3100000.0       59.00           2018-01-15      3
# 23696            18   2500000.0       56.70           2018-02-11      2
# 23697            13  11475000.0       76.75           2017-03-28      2
# 23698             4   1350000.0       32.30           2017-07-21      1
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  \
# 0                2.70            16        51.00      8         False
# 1                 NaN            11        18.60      1         False
# 2                 NaN             5        34.30      4         False
# 4                3.03            14        32.00     13         False
# 5                 NaN            12        14.40      5         False
# ...               ...           ...          ...    ...           ...
# 23693            2.60             9        40.00      8         False
# 23695             NaN             5        38.00      4         False
# 23696             NaN             3        29.70      1         False
# 23697            3.00            17        46.05     12         False
# 23698            2.50             5        12.30      1         False
#
#        is_studio  open_plan  kitchen_area  balcony              locality_name  \
# 0          False      False        25.000        0            Санкт-Петербург
# 1          False      False        11.000        2             поселок Шушары
# 2          False      False         8.300        0            Санкт-Петербург
# 4          False      False        41.000        0            Санкт-Петербург
# 5          False      False         9.100        0  городской поселок Янино-1
# ...          ...        ...           ...      ...                        ...
# 23693      False      False         8.000        0                   Петергоф
# 23695      False      False         8.500        0                      Тосно
# 23696      False      False         9.639        0           село Рождествено
# 23697      False      False        23.300        2            Санкт-Петербург
# 23698      False      False         9.000        0        поселок Новый Учхоз
#
#        airports_nearest  city_centers_nearest  parks_around_3000  \
# 0               18863.0               16028.0                1.0
# 1               12817.0               18603.0                0.0
# 2               21741.0               13933.0                1.0
# 4               31856.0                8098.0                2.0
# 5                   0.0                   NaN                NaN
# ...                 ...                   ...                ...
# 23693           45602.0               34104.0                1.0
# 23695               0.0                   NaN                NaN
# 23696               0.0                   NaN                NaN
# 23697           39140.0               10364.0                2.0
# 23698               0.0                   NaN                NaN
#
#        parks_nearest  ponds_around_3000  ponds_nearest  days_exposition  \
# 0              482.0                2.0          755.0              NaN
# 1                NaN                0.0            NaN             81.0
# 2               90.0                2.0          574.0            558.0
# 4              112.0                1.0           48.0            121.0
# 5                NaN                NaN            NaN             55.0
# ...              ...                ...            ...              ...
# 23693          352.0                1.0          675.0            239.0
# 23695            NaN                NaN            NaN             45.0
# 23696            NaN                NaN            NaN              NaN
# 23697          173.0                3.0          196.0            602.0
# 23698            NaN                NaN            NaN              NaN
#
#       area_category
# 0           too_big
# 1            medium
# 2               big
# 4           too_big
# 5             small
# ...             ...
# 23693           big
# 23695           big
# 23696           big
# 23697       too_big
# 23698         small
#
# [22259 rows x 23 columns]

# %%
for t in data['locality_name'].unique():
    try:
        data.loc[((data['locality_name']==t)&(data['city_centers_nearest'].isna())),'city_centers_nearest'] =\
        data.loc[(data['locality_name']==t),'city_centers_nearest'].median()
    except:
        data.loc[((data['locality_name']==t)&(data['city_centers_nearest'].isna())), 'city_centers_nearest'].fillna(0)
data
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 0                20  13000000.0      108.00           2019-03-07      3
# 1                 7   3350000.0       40.40           2018-12-04      1
# 2                10   5196000.0       56.00           2015-08-20      2
# 4                 2  10000000.0      100.00           2018-06-19      2
# 5                10   2890000.0       30.40           2018-09-10      1
# ...             ...         ...         ...                  ...    ...
# 23693             9   4600000.0       62.40           2016-08-05      3
# 23695            14   3100000.0       59.00           2018-01-15      3
# 23696            18   2500000.0       56.70           2018-02-11      2
# 23697            13  11475000.0       76.75           2017-03-28      2
# 23698             4   1350000.0       32.30           2017-07-21      1
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  \
# 0                2.70            16        51.00      8         False
# 1                 NaN            11        18.60      1         False
# 2                 NaN             5        34.30      4         False
# 4                3.03            14        32.00     13         False
# 5                 NaN            12        14.40      5         False
# ...               ...           ...          ...    ...           ...
# 23693            2.60             9        40.00      8         False
# 23695             NaN             5        38.00      4         False
# 23696             NaN             3        29.70      1         False
# 23697            3.00            17        46.05     12         False
# 23698            2.50             5        12.30      1         False
#
#        is_studio  open_plan  kitchen_area  balcony              locality_name  \
# 0          False      False        25.000        0            Санкт-Петербург
# 1          False      False        11.000        2             поселок Шушары
# 2          False      False         8.300        0            Санкт-Петербург
# 4          False      False        41.000        0            Санкт-Петербург
# 5          False      False         9.100        0  городской поселок Янино-1
# ...          ...        ...           ...      ...                        ...
# 23693      False      False         8.000        0                   Петергоф
# 23695      False      False         8.500        0                      Тосно
# 23696      False      False         9.639        0           село Рождествено
# 23697      False      False        23.300        2            Санкт-Петербург
# 23698      False      False         9.000        0        поселок Новый Учхоз
#
#        airports_nearest  city_centers_nearest  parks_around_3000  \
# 0               18863.0               16028.0                1.0
# 1               12817.0               18603.0                0.0
# 2               21741.0               13933.0                1.0
# 4               31856.0                8098.0                2.0
# 5                   0.0                   NaN                NaN
# ...                 ...                   ...                ...
# 23693           45602.0               34104.0                1.0
# 23695               0.0                   NaN                NaN
# 23696               0.0                   NaN                NaN
# 23697           39140.0               10364.0                2.0
# 23698               0.0                   NaN                NaN
#
#        parks_nearest  ponds_around_3000  ponds_nearest  days_exposition  \
# 0              482.0                2.0          755.0              NaN
# 1                NaN                0.0            NaN             81.0
# 2               90.0                2.0          574.0            558.0
# 4              112.0                1.0           48.0            121.0
# 5                NaN                NaN            NaN             55.0
# ...              ...                ...            ...              ...
# 23693          352.0                1.0          675.0            239.0
# 23695            NaN                NaN            NaN             45.0
# 23696            NaN                NaN            NaN              NaN
# 23697          173.0                3.0          196.0            602.0
# 23698            NaN                NaN            NaN              NaN
#
#       area_category
# 0           too_big
# 1            medium
# 2               big
# 4           too_big
# 5             small
# ...             ...
# 23693           big
# 23695           big
# 23696           big
# 23697       too_big
# 23698         small
#
# [22259 rows x 23 columns]

# %%
data['city_centers_nearest'] = data['city_centers_nearest'].fillna(0)

# %%
data
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 0                20  13000000.0      108.00           2019-03-07      3
# 1                 7   3350000.0       40.40           2018-12-04      1
# 2                10   5196000.0       56.00           2015-08-20      2
# 4                 2  10000000.0      100.00           2018-06-19      2
# 5                10   2890000.0       30.40           2018-09-10      1
# ...             ...         ...         ...                  ...    ...
# 23693             9   4600000.0       62.40           2016-08-05      3
# 23695            14   3100000.0       59.00           2018-01-15      3
# 23696            18   2500000.0       56.70           2018-02-11      2
# 23697            13  11475000.0       76.75           2017-03-28      2
# 23698             4   1350000.0       32.30           2017-07-21      1
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  \
# 0                2.70            16        51.00      8         False
# 1                 NaN            11        18.60      1         False
# 2                 NaN             5        34.30      4         False
# 4                3.03            14        32.00     13         False
# 5                 NaN            12        14.40      5         False
# ...               ...           ...          ...    ...           ...
# 23693            2.60             9        40.00      8         False
# 23695             NaN             5        38.00      4         False
# 23696             NaN             3        29.70      1         False
# 23697            3.00            17        46.05     12         False
# 23698            2.50             5        12.30      1         False
#
#        is_studio  open_plan  kitchen_area  balcony              locality_name  \
# 0          False      False        25.000        0            Санкт-Петербург
# 1          False      False        11.000        2             поселок Шушары
# 2          False      False         8.300        0            Санкт-Петербург
# 4          False      False        41.000        0            Санкт-Петербург
# 5          False      False         9.100        0  городской поселок Янино-1
# ...          ...        ...           ...      ...                        ...
# 23693      False      False         8.000        0                   Петергоф
# 23695      False      False         8.500        0                      Тосно
# 23696      False      False         9.639        0           село Рождествено
# 23697      False      False        23.300        2            Санкт-Петербург
# 23698      False      False         9.000        0        поселок Новый Учхоз
#
#        airports_nearest  city_centers_nearest  parks_around_3000  \
# 0               18863.0               16028.0                1.0
# 1               12817.0               18603.0                0.0
# 2               21741.0               13933.0                1.0
# 4               31856.0                8098.0                2.0
# 5                   0.0                   0.0                NaN
# ...                 ...                   ...                ...
# 23693           45602.0               34104.0                1.0
# 23695               0.0                   0.0                NaN
# 23696               0.0                   0.0                NaN
# 23697           39140.0               10364.0                2.0
# 23698               0.0                   0.0                NaN
#
#        parks_nearest  ponds_around_3000  ponds_nearest  days_exposition  \
# 0              482.0                2.0          755.0              NaN
# 1                NaN                0.0            NaN             81.0
# 2               90.0                2.0          574.0            558.0
# 4              112.0                1.0           48.0            121.0
# 5                NaN                NaN            NaN             55.0
# ...              ...                ...            ...              ...
# 23693          352.0                1.0          675.0            239.0
# 23695            NaN                NaN            NaN             45.0
# 23696            NaN                NaN            NaN              NaN
# 23697          173.0                3.0          196.0            602.0
# 23698            NaN                NaN            NaN              NaN
#
#       area_category
# 0           too_big
# 1            medium
# 2               big
# 4           too_big
# 5             small
# ...             ...
# 23693           big
# 23695           big
# 23696           big
# 23697       too_big
# 23698         small
#
# [22259 rows x 23 columns]

# %%
data.isna().sum()
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height           8672
# floors_total                0
# living_area                 0
# floor                       0
# is_apartment                0
# is_studio                   0
# open_plan                   0
# kitchen_area                0
# balcony                     0
# locality_name               0
# airports_nearest            0
# city_centers_nearest        0
# parks_around_3000        5451
# parks_nearest           15063
# ponds_around_3000        5451
# ponds_nearest           14053
# days_exposition          2840
# area_category               0
# dtype: int64

# %%
data.describe()
# Out:
#        total_images    last_price    total_area         rooms  ceiling_height  \
# count  22259.000000  2.225900e+04  22259.000000  22259.000000    13587.000000
# mean       9.789389  5.272433e+06     54.142118      1.943394        2.700552
# std        5.598041  3.311203e+06     19.086545      0.895137        0.269604
# min        0.000000  1.219000e+04     12.000000      0.000000        1.000000
# 25%        6.000000  3.350000e+06     39.300000      1.000000        2.500000
# 50%        9.000000  4.500000e+06     50.000000      2.000000        2.630000
# 75%       14.000000  6.280000e+06     65.200000      3.000000        2.770000
# max       50.000000  5.300000e+07    112.500000      6.000000       10.000000
#
#        floors_total   living_area         floor  kitchen_area       balcony  \
# count  22259.000000  22259.000000  22259.000000  22259.000000  22259.000000
# mean      10.794690     31.072767      5.904578      9.732835      0.598814
# std        6.635605     13.211708      4.898655      4.247969      0.952870
# min        1.000000      2.000000      1.000000      1.300000      0.000000
# 25%        5.000000     18.600000      2.000000      7.000000      0.000000
# 50%        9.000000     29.700000      4.000000      9.000000      0.000000
# 75%       16.000000     40.000000      8.000000     11.100000      1.000000
# max       60.000000    101.000000     33.000000     55.700000      5.000000
#
#        airports_nearest  city_centers_nearest  parks_around_3000  \
# count      22259.000000          22259.000000       16808.000000
# mean       23203.091469          11099.939485           0.578177
# std        16939.509622           9717.066185           0.777475
# min            0.000000              0.000000           0.000000
# 25%        11194.000000           1638.500000           0.000000
# 50%        22431.000000          11594.000000           0.000000
# 75%        35874.500000          15438.500000           1.000000
# max        84869.000000          65968.000000           3.000000
#
#        parks_nearest  ponds_around_3000  ponds_nearest  days_exposition
# count    7196.000000       16808.000000    8206.000000     19419.000000
# mean      493.715536           0.735305     525.764319       174.595036
# std       340.173166           0.914093     277.281750       212.686207
# min         1.000000           0.000000      13.000000         1.000000
# 25%       289.000000           0.000000     304.000000        44.000000
# 50%       457.500000           0.000000     512.000000        92.000000
# 75%       616.000000           1.000000     733.750000       222.000000
# max      3190.000000           3.000000    1344.000000      1580.000000

# %% [markdown]
# **Вывод**
#
# В изначальной таблице было много пропусков, некоторые колонки нужно было привести к нужному типу данных, а также заполнить пропуски подходящими данными (если это возможно)
#
# После обработки данных мы заполнили пропуски по колонкам *rooms, living_area,is_apartment, kitchen_area, balcony а также airports_nearest*, привели колонки *balcony, floors_total, is_apartment и first_day_exposition* к нужному типу данных, а также избавились от явных и неявных дупликатов.

# %%
data.hist(figsize=(20,20));

# %% [markdown]
# ### Посчитайте и добавьте в таблицу новые столбцы

# %%
data['one_metr'] = (data['last_price']/data['total_area']).round()
data
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 0                20  13000000.0      108.00           2019-03-07      3
# 1                 7   3350000.0       40.40           2018-12-04      1
# 2                10   5196000.0       56.00           2015-08-20      2
# 4                 2  10000000.0      100.00           2018-06-19      2
# 5                10   2890000.0       30.40           2018-09-10      1
# ...             ...         ...         ...                  ...    ...
# 23693             9   4600000.0       62.40           2016-08-05      3
# 23695            14   3100000.0       59.00           2018-01-15      3
# 23696            18   2500000.0       56.70           2018-02-11      2
# 23697            13  11475000.0       76.75           2017-03-28      2
# 23698             4   1350000.0       32.30           2017-07-21      1
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  \
# 0                2.70            16        51.00      8         False
# 1                 NaN            11        18.60      1         False
# 2                 NaN             5        34.30      4         False
# 4                3.03            14        32.00     13         False
# 5                 NaN            12        14.40      5         False
# ...               ...           ...          ...    ...           ...
# 23693            2.60             9        40.00      8         False
# 23695             NaN             5        38.00      4         False
# 23696             NaN             3        29.70      1         False
# 23697            3.00            17        46.05     12         False
# 23698            2.50             5        12.30      1         False
#
#        is_studio  open_plan  kitchen_area  balcony              locality_name  \
# 0          False      False        25.000        0            Санкт-Петербург
# 1          False      False        11.000        2             поселок Шушары
# 2          False      False         8.300        0            Санкт-Петербург
# 4          False      False        41.000        0            Санкт-Петербург
# 5          False      False         9.100        0  городской поселок Янино-1
# ...          ...        ...           ...      ...                        ...
# 23693      False      False         8.000        0                   Петергоф
# 23695      False      False         8.500        0                      Тосно
# 23696      False      False         9.639        0           село Рождествено
# 23697      False      False        23.300        2            Санкт-Петербург
# 23698      False      False         9.000        0        поселок Новый Учхоз
#
#        airports_nearest  city_centers_nearest  parks_around_3000  \
# 0               18863.0               16028.0                1.0
# 1               12817.0               18603.0                0.0
# 2               21741.0               13933.0                1.0
# 4               31856.0                8098.0                2.0
# 5                   0.0                   0.0                NaN
# ...                 ...                   ...                ...
# 23693           45602.0               34104.0                1.0
# 23695               0.0                   0.0                NaN
# 23696               0.0                   0.0                NaN
# 23697           39140.0               10364.0                2.0
# 23698               0.0                   0.0                NaN
#
#        parks_nearest  ponds_around_3000  ponds_nearest  days_exposition  \
# 0              482.0                2.0          755.0              NaN
# 1                NaN                0.0            NaN             81.0
# 2               90.0                2.0          574.0            558.0
# 4              112.0                1.0           48.0            121.0
# 5                NaN                NaN            NaN             55.0
# ...              ...                ...            ...              ...
# 23693          352.0                1.0          675.0            239.0
# 23695            NaN                NaN            NaN             45.0
# 23696            NaN                NaN            NaN              NaN
# 23697          173.0                3.0          196.0            602.0
# 23698            NaN                NaN            NaN              NaN
#
#       area_category  one_metr
# 0           too_big  120370.0
# 1            medium   82921.0
# 2               big   92786.0
# 4           too_big  100000.0
# 5             small   95066.0
# ...             ...       ...
# 23693           big   73718.0
# 23695           big   52542.0
# 23696           big   44092.0
# 23697       too_big  149511.0
# 23698         small   41796.0
#
# [22259 rows x 24 columns]

# %%
data['km_from_city_center'] = (data['city_centers_nearest'] / 1000).round()
data
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 0                20  13000000.0      108.00           2019-03-07      3
# 1                 7   3350000.0       40.40           2018-12-04      1
# 2                10   5196000.0       56.00           2015-08-20      2
# 4                 2  10000000.0      100.00           2018-06-19      2
# 5                10   2890000.0       30.40           2018-09-10      1
# ...             ...         ...         ...                  ...    ...
# 23693             9   4600000.0       62.40           2016-08-05      3
# 23695            14   3100000.0       59.00           2018-01-15      3
# 23696            18   2500000.0       56.70           2018-02-11      2
# 23697            13  11475000.0       76.75           2017-03-28      2
# 23698             4   1350000.0       32.30           2017-07-21      1
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  \
# 0                2.70            16        51.00      8         False
# 1                 NaN            11        18.60      1         False
# 2                 NaN             5        34.30      4         False
# 4                3.03            14        32.00     13         False
# 5                 NaN            12        14.40      5         False
# ...               ...           ...          ...    ...           ...
# 23693            2.60             9        40.00      8         False
# 23695             NaN             5        38.00      4         False
# 23696             NaN             3        29.70      1         False
# 23697            3.00            17        46.05     12         False
# 23698            2.50             5        12.30      1         False
#
#        is_studio  open_plan  kitchen_area  balcony              locality_name  \
# 0          False      False        25.000        0            Санкт-Петербург
# 1          False      False        11.000        2             поселок Шушары
# 2          False      False         8.300        0            Санкт-Петербург
# 4          False      False        41.000        0            Санкт-Петербург
# 5          False      False         9.100        0  городской поселок Янино-1
# ...          ...        ...           ...      ...                        ...
# 23693      False      False         8.000        0                   Петергоф
# 23695      False      False         8.500        0                      Тосно
# 23696      False      False         9.639        0           село Рождествено
# 23697      False      False        23.300        2            Санкт-Петербург
# 23698      False      False         9.000        0        поселок Новый Учхоз
#
#        airports_nearest  city_centers_nearest  parks_around_3000  \
# 0               18863.0               16028.0                1.0
# 1               12817.0               18603.0                0.0
# 2               21741.0               13933.0                1.0
# 4               31856.0                8098.0                2.0
# 5                   0.0                   0.0                NaN
# ...                 ...                   ...                ...
# 23693           45602.0               34104.0                1.0
# 23695               0.0                   0.0                NaN
# 23696               0.0                   0.0                NaN
# 23697           39140.0               10364.0                2.0
# 23698               0.0                   0.0                NaN
#
#        parks_nearest  ponds_around_3000  ponds_nearest  days_exposition  \
# 0              482.0                2.0          755.0              NaN
# 1                NaN                0.0            NaN             81.0
# 2               90.0                2.0          574.0            558.0
# 4              112.0                1.0           48.0            121.0
# 5                NaN                NaN            NaN             55.0
# ...              ...                ...            ...              ...
# 23693          352.0                1.0          675.0            239.0
# 23695            NaN                NaN            NaN             45.0
# 23696            NaN                NaN            NaN              NaN
# 23697          173.0                3.0          196.0            602.0
# 23698            NaN                NaN            NaN              NaN
#
#       area_category  one_metr  km_from_city_center
# 0           too_big  120370.0                 16.0
# 1            medium   82921.0                 19.0
# 2               big   92786.0                 14.0
# 4           too_big  100000.0                  8.0
# 5             small   95066.0                  0.0
# ...             ...       ...                  ...
# 23693           big   73718.0                 34.0
# 23695           big   52542.0                  0.0
# 23696           big   44092.0                  0.0
# 23697       too_big  149511.0                 10.0
# 23698         small   41796.0                  0.0
#
# [22259 rows x 25 columns]

# %%
def floor(row):
    if row['floor'] == 1:
        return 'Первый'
    elif row['floor'] == row['floors_total']:
        return 'Последний'
    else:
        return 'Другой'

# %%
data['floor_type'] = data.apply(floor, axis=1)

# %%
data['year'] = pd.DatetimeIndex(data['first_day_exposition']).year
data['month'] = pd.DatetimeIndex(data['first_day_exposition']).month
data['day'] = pd.DatetimeIndex(data['first_day_exposition']).weekday
data
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 0                20  13000000.0      108.00           2019-03-07      3
# 1                 7   3350000.0       40.40           2018-12-04      1
# 2                10   5196000.0       56.00           2015-08-20      2
# 4                 2  10000000.0      100.00           2018-06-19      2
# 5                10   2890000.0       30.40           2018-09-10      1
# ...             ...         ...         ...                  ...    ...
# 23693             9   4600000.0       62.40           2016-08-05      3
# 23695            14   3100000.0       59.00           2018-01-15      3
# 23696            18   2500000.0       56.70           2018-02-11      2
# 23697            13  11475000.0       76.75           2017-03-28      2
# 23698             4   1350000.0       32.30           2017-07-21      1
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  \
# 0                2.70            16        51.00      8         False
# 1                 NaN            11        18.60      1         False
# 2                 NaN             5        34.30      4         False
# 4                3.03            14        32.00     13         False
# 5                 NaN            12        14.40      5         False
# ...               ...           ...          ...    ...           ...
# 23693            2.60             9        40.00      8         False
# 23695             NaN             5        38.00      4         False
# 23696             NaN             3        29.70      1         False
# 23697            3.00            17        46.05     12         False
# 23698            2.50             5        12.30      1         False
#
#        is_studio  open_plan  kitchen_area  balcony              locality_name  \
# 0          False      False        25.000        0            Санкт-Петербург
# 1          False      False        11.000        2             поселок Шушары
# 2          False      False         8.300        0            Санкт-Петербург
# 4          False      False        41.000        0            Санкт-Петербург
# 5          False      False         9.100        0  городской поселок Янино-1
# ...          ...        ...           ...      ...                        ...
# 23693      False      False         8.000        0                   Петергоф
# 23695      False      False         8.500        0                      Тосно
# 23696      False      False         9.639        0           село Рождествено
# 23697      False      False        23.300        2            Санкт-Петербург
# 23698      False      False         9.000        0        поселок Новый Учхоз
#
#        airports_nearest  city_centers_nearest  parks_around_3000  \
# 0               18863.0               16028.0                1.0
# 1               12817.0               18603.0                0.0
# 2               21741.0               13933.0                1.0
# 4               31856.0                8098.0                2.0
# 5                   0.0                   0.0                NaN
# ...                 ...                   ...                ...
# 23693           45602.0               34104.0                1.0
# 23695               0.0                   0.0                NaN
# 23696               0.0                   0.0                NaN
# 23697           39140.0               10364.0                2.0
# 23698               0.0                   0.0                NaN
#
#        parks_nearest  ponds_around_3000  ponds_nearest  days_exposition  \
# 0              482.0                2.0          755.0              NaN
# 1                NaN                0.0            NaN             81.0
# 2               90.0                2.0          574.0            558.0
# 4              112.0                1.0           48.0            121.0
# 5                NaN                NaN            NaN             55.0
# ...              ...                ...            ...              ...
# 23693          352.0                1.0          675.0            239.0
# 23695            NaN                NaN            NaN             45.0
# 23696            NaN                NaN            NaN              NaN
# 23697          173.0                3.0          196.0            602.0
# 23698            NaN                NaN            NaN              NaN
#
#       area_category  one_metr  km_from_city_center floor_type  year  month  \
# 0           too_big  120370.0                 16.0     Другой  2019      3
# 1            medium   82921.0                 19.0     Первый  2018     12
# 2               big   92786.0                 14.0     Другой  2015      8
# 4           too_big  100000.0                  8.0     Другой  2018      6
# 5             small   95066.0                  0.0     Другой  2018      9
# ...             ...       ...                  ...        ...   ...    ...
# 23693           big   73718.0                 34.0     Другой  2016      8
# 23695           big   52542.0                  0.0     Другой  2018      1
# 23696           big   44092.0                  0.0     Первый  2018      2
# 23697       too_big  149511.0                 10.0     Другой  2017      3
# 23698         small   41796.0                  0.0     Первый  2017      7
#
#        day
# 0        3
# 1        1
# 2        3
# 4        1
# 5        0
# ...    ...
# 23693    4
# 23695    0
# 23696    6
# 23697    1
# 23698    4
#
# [22259 rows x 29 columns]

# %%
data.groupby('day')[['last_price']].count()
# Out:
#      last_price
# day
# 0          3406
# 1          3941
# 2          3704
# 3          4000
# 4          3778
# 5          1826
# 6          1604

# %%
data.groupby('year')[['last_price']].count()
# Out:
#       last_price
# year
# 2014         102
# 2015        1032
# 2016        2562
# 2017        7699
# 2018        8132
# 2019        2732

# %%
data.groupby('month')[['last_price']].count()
# Out:
#        last_price
# month
# 1            1401
# 2            2488
# 3            2449
# 4            2240
# 5            1182
# 6            1660
# 7            1578
# 8            1652
# 9            1851
# 10           2007
# 11           2215
# 12           1536

# %%
df7 = data.groupby('floor_type')[['last_price']].count().copy()
df7['perc'] = (df7['last_price']/len(data))*100
df7
# Out:
#             last_price       perc
# floor_type
# Другой           16381  73.592704
# Первый            2820  12.669033
# Последний         3058  13.738263

# %% [markdown]
# **Вывод**
#
# Больше всего объявлений было выставлено в будние дни - конкретно - в четверг, и меньше всего в выходные
#
# Больше всего объявлений было в 2017 и 2018 годах. Возможно - раньше меньше пользовались данным сервисом для продажи квартир, или продавали через другие агентства/искали покупателя сами. При том, в 2019 году количество заявлений резко уменьшилось.
#
# Также, чаще всего объявления выкладывались в конце зимы-начале весны и конце осени-начале зимы. Возможно это связано с какими либо праздниками. При том, в мае было меньше всего новых объявлений
#
# Среди этажей - примерно одинаковое количество объявлений было по объектам на первом/последнем этаже - 12-13% от общего количества объектов

# %% [markdown]
# ### Проведите исследовательский анализ данных

# %%
data.hist(figsize=(20,20));

# %%
data['total_images'].hist(range=(0,30), figsize=(5,5));

# %% [markdown]
# Более 9 тысяч суммарно объявлений с наличием фото от 6 до 12. Также на графике видно, что есть объекты с фотографиями в количестве > 21

# %%
data.boxplot(column='total_images');

# %% [markdown]
# Но в данном случае, такие объекты являются выбросами

# %%
data['last_price'].hist(range=(0,3e+07),figsize=(5,5));

# %% [markdown]
# Пиковое значение - при стоимости квартир около 5 миллионов - более 12000 позиций с такой ценой

# %%
data['last_price'].hist(range=(0,1e+05),figsize=(5,5));

# %% [markdown]
# Значений в нуле нет - и это хорошо - но вот стоимость объекта до 200000 - странно, посмотрим:

# %%
data[data['last_price']<=50000]
# Out:
#       total_images  last_price  total_area first_day_exposition  rooms  \
# 8793             7     12190.0       109.0           2019-03-20      2
#
#       ceiling_height  floors_total  living_area  floor  is_apartment  \
# 8793            2.75            25         32.0     25         False
#
#       is_studio  open_plan  kitchen_area  balcony    locality_name  \
# 8793      False      False          40.5        0  Санкт-Петербург
#
#       airports_nearest  city_centers_nearest  parks_around_3000  \
# 8793           36421.0                9176.0                1.0
#
#       parks_nearest  ponds_around_3000  ponds_nearest  days_exposition  \
# 8793          805.0                0.0            NaN              8.0
#
#      area_category  one_metr  km_from_city_center floor_type  year  month  day
# 8793       too_big     112.0                  9.0  Последний  2019      3    2

# %% [markdown]
# Очень странная квартира за такую стоимость, с 100+ площадью и провисевшая на сервисе 8 дней. Не могу сказать точно, это была ошибка при вывешивании объявления и ее быстро удалили вместе с объявлением, или же это была ошибка в данных, но квартиру быстро купили, и менять ничего не пришлось.

# %%
data['total_area'].hist(figsize=(5,5));

# %%
data['total_area'].hist(range=(20,50),figsize=(5,5));

# %% [markdown]
# Пик на гистограмме наблюдается от 29 до 47 квадратных метров - больше всего квартир именно с этим метражем. В данной диаграмме уже не наблюдается выбросов как таковый, только значения < 21 смущают:

# %%
data['total_area'].hist(range=(0,21),figsize=(5,5));

# %%
data[data['total_area']<20]
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 716               5   1500000.0       17.00           2017-06-07      0
# 4542             12   3300000.0       18.00           2018-11-07      1
# 5855              3    945750.0       19.50           2017-09-18      0
# 6084              6    770000.0       18.00           2017-10-16      1
# 8454              7   2250000.0       19.00           2019-03-12      0
# 8729              9   2200000.0       18.40           2018-08-20      1
# 8755              1   1350000.0       18.80           2017-11-22      0
# 8886             10   2450000.0       15.50           2018-08-22      0
# 9157              0   3400000.0       17.60           2018-03-18      1
# 9412              5   2100000.0       16.00           2017-12-10      0
# 9817              8   2190000.0       19.00           2018-10-12      0
# 10208             3   1900000.0       17.00           2018-08-14      1
# 12040             5   1900000.0       15.00           2018-06-27      1
# 12881             5   1500000.0       18.50           2017-12-13      1
# 12996             8   1900000.0       18.00           2019-01-25      0
# 16949             9   1550000.0       15.00           2018-08-21      1
# 17961             3   1400000.0       13.00           2017-12-03      1
# 19311            12   2190000.0       18.00           2015-03-29      1
# 19546             3   1850000.0       13.00           2019-03-11      1
# 19558             2   1686000.0       13.20           2018-12-17      1
# 19642             5   1190000.0       14.00           2018-07-29      1
# 19807             0   3800000.0       13.00           2018-07-04      1
# 19904             4   2400000.0       12.00           2017-07-19      1
# 20714             7   1200000.0       18.00           2018-01-04      1
# 21802             6   1737000.0       17.78           2018-11-22      1
# 22356             6   2050000.0       17.20           2019-01-13      1
# 23191             3   1900000.0       18.90           2016-04-04      1
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  \
# 716              2.70             9        12.00      1         False
# 4542             3.50             5         9.00      2         False
# 5855             2.76             3        12.70      2         False
# 6084              NaN             5        13.00      4         False
# 8454             3.00             6        11.40      2         False
# 8729             2.52             3        14.00      3         False
# 8755             2.75            19        15.80      1         False
# 8886              NaN             5        10.00      2         False
# 9157              NaN             5        15.00      2         False
# 9412              NaN             6        13.00      1         False
# 9817             3.50             5        15.00      1         False
# 10208            2.75             4        13.00      2         False
# 12040            2.50             5         9.00      1         False
# 12881             NaN             5        11.10      5         False
# 12996            2.60             5        16.00      3         False
# 16949            2.70             9         9.00      1         False
# 17961            2.60             9         7.80      1         False
# 19311             NaN             2        10.00      1         False
# 19546            3.40             5         7.80      2         False
# 19558             NaN             5         7.92      1         False
# 19642             NaN             5        11.00      1         False
# 19807             NaN             5        10.00      3         False
# 19904            2.55             5        10.00      2         False
# 20714             NaN             4        10.80      4         False
# 21802            2.60             9        15.89      1         False
# 22356            2.77            23        10.32      1         False
# 23191             NaN            16        16.00     12         False
#
#        is_studio  open_plan  kitchen_area  balcony     locality_name  \
# 716         True      False        2.8900        0    поселок Шушары
# 4542       False      False        3.0600        0   Санкт-Петербург
# 5855        True      False        3.3150        0  поселок Дубровка
# 6084       False      False        3.0000        0            Тихвин
# 8454        True      False        3.2300        0   Санкт-Петербург
# 8729       False      False        2.4000        0            Пушкин
# 8755        True      False        3.1960        0   Санкт-Петербург
# 8886        True      False        2.6350        0   Санкт-Петербург
# 9157       False      False        2.9920        0   Санкт-Петербург
# 9412       False       True        2.7200        0   Санкт-Петербург
# 9817        True      False        3.2300        0   Санкт-Петербург
# 10208      False      False        3.0000        0   Санкт-Петербург
# 12040      False      False        2.5500        0      Сосновый Бор
# 12881      False      False        3.1450        0      Сосновый Бор
# 12996       True      False        3.0600        0   Санкт-Петербург
# 16949      False      False        2.5500        0   Санкт-Петербург
# 17961      False      False        2.2100        0   Санкт-Петербург
# 19311      False      False        3.0600        1   Санкт-Петербург
# 19546      False      False        2.2100        0   Санкт-Петербург
# 19558      False      False        2.2440        0   Санкт-Петербург
# 19642      False      False        2.0000        0   Санкт-Петербург
# 19807      False      False        2.2100        0   Санкт-Петербург
# 19904      False      False        2.0400        0   Санкт-Петербург
# 20714      False      False        3.0600        0           Кировск
# 21802      False      False        3.0226        0   Санкт-Петербург
# 22356      False      False        2.9240        0   Санкт-Петербург
# 23191      False      False        3.2130        0             Тосно
#
#        airports_nearest  city_centers_nearest  parks_around_3000  \
# 716             18654.0               29846.0                0.0
# 4542            25157.0                4948.0                2.0
# 5855                0.0                   0.0                NaN
# 6084                0.0                   0.0                NaN
# 8454            12430.0                7316.0                1.0
# 8729            20710.0               30687.0                0.0
# 8755            37636.0               14479.0                0.0
# 8886            24326.0                4589.0                0.0
# 9157            21555.0                1967.0                2.0
# 9412            20735.0                2111.0                2.0
# 9817            29561.0                8264.0                2.0
# 10208           25072.0                5639.0                0.0
# 12040               0.0                   0.0                NaN
# 12881               0.0                   0.0                NaN
# 12996           19573.0               15772.0                2.0
# 16949           51048.0               16376.0                0.0
# 17961           14350.0               15945.0                0.0
# 19311           27056.0                9210.0                0.0
# 19546           24915.0                5483.0                1.0
# 19558           19891.0                4165.0                1.0
# 19642            9898.0               11122.0                0.0
# 19807           21302.0                1242.0                1.0
# 19904           21314.0                 964.0                1.0
# 20714               0.0                   0.0                NaN
# 21802           13289.0               12086.0                0.0
# 22356           33645.0               13513.0                0.0
# 23191               0.0                   0.0                NaN
#
#        parks_nearest  ponds_around_3000  ponds_nearest  days_exposition  \
# 716              NaN                0.0            NaN             40.0
# 4542           349.0                1.0          963.0              9.0
# 5855             NaN                NaN            NaN              3.0
# 6084             NaN                NaN            NaN             90.0
# 8454           238.0                3.0          374.0             44.0
# 8729             NaN                1.0          155.0             59.0
# 8755             NaN                1.0         1127.0            128.0
# 8886             NaN                1.0          446.0             27.0
# 9157           336.0                1.0          309.0            117.0
# 9412           228.0                3.0           72.0              3.0
# 9817           383.0                1.0          781.0             89.0
# 10208            NaN                0.0            NaN              7.0
# 12040            NaN                NaN            NaN             45.0
# 12881            NaN                NaN            NaN             41.0
# 12996          149.0                2.0          496.0             10.0
# 16949            NaN                1.0         1079.0             42.0
# 17961            NaN                1.0          185.0            410.0
# 19311            NaN                1.0          473.0            702.0
# 19546          644.0                0.0            NaN             24.0
# 19558          361.0                1.0          155.0             19.0
# 19642            NaN                0.0            NaN              4.0
# 19807          592.0                3.0           27.0              9.0
# 19904          886.0                2.0           45.0            200.0
# 20714            NaN                NaN            NaN             45.0
# 21802            NaN                0.0            NaN             66.0
# 22356            NaN                0.0            NaN              7.0
# 23191            NaN                NaN            NaN            115.0
#
#       area_category  one_metr  km_from_city_center floor_type  year  month  \
# 716           small   88235.0                 30.0     Первый  2017      6
# 4542          small  183333.0                  5.0     Другой  2018     11
# 5855          small   48500.0                  0.0     Другой  2017      9
# 6084          small   42778.0                  0.0     Другой  2017     10
# 8454          small  118421.0                  7.0     Другой  2019      3
# 8729          small  119565.0                 31.0  Последний  2018      8
# 8755          small   71809.0                 14.0     Первый  2017     11
# 8886          small  158065.0                  5.0     Другой  2018      8
# 9157          small  193182.0                  2.0     Другой  2018      3
# 9412          small  131250.0                  2.0     Первый  2017     12
# 9817          small  115263.0                  8.0     Первый  2018     10
# 10208         small  111765.0                  6.0     Другой  2018      8
# 12040         small  126667.0                  0.0     Первый  2018      6
# 12881         small   81081.0                  0.0  Последний  2017     12
# 12996         small  105556.0                 16.0     Другой  2019      1
# 16949         small  103333.0                 16.0     Первый  2018      8
# 17961         small  107692.0                 16.0     Первый  2017     12
# 19311         small  121667.0                  9.0     Первый  2015      3
# 19546         small  142308.0                  5.0     Другой  2019      3
# 19558         small  127727.0                  4.0     Первый  2018     12
# 19642         small   85000.0                 11.0     Первый  2018      7
# 19807         small  292308.0                  1.0     Другой  2018      7
# 19904         small  200000.0                  1.0     Другой  2017      7
# 20714         small   66667.0                  0.0  Последний  2018      1
# 21802         small   97694.0                 12.0     Первый  2018     11
# 22356         small  119186.0                 14.0     Первый  2019      1
# 23191         small  100529.0                  0.0     Другой  2016      4
#
#        day
# 716      2
# 4542     2
# 5855     0
# 6084     0
# 8454     1
# 8729     0
# 8755     2
# 8886     2
# 9157     6
# 9412     6
# 9817     4
# 10208    1
# 12040    2
# 12881    2
# 12996    4
# 16949    1
# 17961    6
# 19311    6
# 19546    0
# 19558    0
# 19642    6
# 19807    2
# 19904    2
# 20714    3
# 21802    3
# 22356    6
# 23191    0

# %% [markdown]
# В целом, данные по этим квартирам выглядят нормально, ничего критически отличающегося я не заметила

# %%
data['first_day_exposition'].hist(figsize=(5,5),xrot=90);

# %% [markdown]
# По гистограмме видно 2 пика - во второй половине 2017 года и во второй половине 2018 года.
#
# Однако, что-то непонятное произошло в конце 2016 года.

# %%
data['rooms'].hist(figsize=(5,5));

# %% [markdown]
# Я уже замечала этот несколько объектов с 0 комнат и нормальным метражем, однако там либо стоит *open plan = True*, ничего делать не нужно, т.к. там действительно нет комнат как таковых, либо же это студия.

# %%
data[(data['rooms']==0)&((data['is_studio'].isna())|(data['open_plan'].isna()))]
# Out:
# Empty DataFrame
# Columns: [total_images, last_price, total_area, first_day_exposition, rooms, ceiling_height, floors_total, living_area, floor, is_apartment, is_studio, open_plan, kitchen_area, balcony, locality_name, airports_nearest, city_centers_nearest, parks_around_3000, parks_nearest, ponds_around_3000, ponds_nearest, days_exposition, area_category, one_metr, km_from_city_center, floor_type, year, month, day]
# Index: []

# %%
data['ceiling_height'].hist(figsize=(5,5));

# %%
data['floors_total'].hist(range=(0,40),figsize=(5,5));

# %% [markdown]
# На данном графике пик - на значении с 4 по 8, и даже встречаются дома с 27+ этажами, но построим более приближенный, чтобы оценить детали:

# %%
data['floors_total'].hist(range=(0,11),figsize=(5,5));

# %% [markdown]
# Здесь уже видно, что пик приходит на дома с 5ю этажами и 9 этажами - самый часто-встречающийся тип жилых домов

# %%
data['living_area'].hist(figsize=(5,5));

# %%
data['living_area'].hist(range=(0,40),figsize=(5,5));

# %% [markdown]
# Значений в 0 нет - прекрасно. Чаще всего встречаются квартиры с 16-20 метрами жилой площади, и чуть отстают по частоте - 28-32 $м^2$

# %%
data['floor'].hist(figsize=(5,5));

# %%
data['floor'].hist(figsize=(5,5),range=(0,10));

# %% [markdown]
# Однако, больше всего квартир на 2м этаже, или на 9 - и подозреваю, эти квартиры последние в своем доме

# %%
data['kitchen_area'].hist(figsize=(5,5));

# %% [markdown]
# Средним квартирами - средний размер кухни

# %%
data['balcony'].hist(figsize=(5,5));

# %% [markdown]
# Либо в квартире нет балкона вообще, либо 1 или 2 - больше встречается редко

# %%
data['airports_nearest'].hist(figsize=(5,5),xrot=90);

# %%
data['airports_nearest'].hist(figsize=(5,5),range=(0,10000));

# %% [markdown]
# Либо аэропортов нет вообще - там где пропуски мы заполняли нулями (аэропорт не может быть в центре села), либо до аэропорта примерно 20км

# %%
data['city_centers_nearest'].hist(figsize=(5,5));

# %%
data['city_centers_nearest'].hist(figsize=(5,5),range=(0,20000));

# %% [markdown]
# Аналогично аэропортам, либо дом стоит в центре города (поселка, села), либо - пик - в 12 км от центра города.
#
# Есть дома и дальше, и ближе, но самые частые значения - в пределах 20 км

# %%
data['parks_around_3000'].hist(figsize=(5,5));

# %% [markdown]
# Чаще всего парков вокруг нет - мне кажется, либо это деревня/поселок, где нет облагороженных парков, а лишь лес вокруг, либо просто жилой район без зеленой зоны.
#
# Значения типа NaN тут не учитываются

# %%
data['parks_nearest'].hist(figsize=(5,5));

# %% [markdown]
# Судя по этому графику, чаще всего встречаются объекты, где парки в зоне пешей доступности, гораздо реже - где до парка > 900 м

# %%
data['ponds_around_3000'].hist(figsize=(5,5));

# %% [markdown]
# Как и в случае с парками - чаще всего водоемов поблизости нет.

# %%
data['ponds_nearest'].hist(figsize=(5,5));

# %% [markdown]
# Среди тех объектов, рядом с которыми есть водоёмы - бОльшее количество находятся в пределах 900 м

# %%
data['area_category'].hist(figsize=(5,5));

# %% [markdown]
# Разбивка объектов по типу площади примерно одинакова - то есть у нас примерно одинаковое количество квартир с разной площадью

# %%
data['floor_type'].hist(figsize=(5,5));

# %% [markdown]
# Чаще всего встречаются объекты на "другом" этаже - первый и последний занимают где то 12-13% от всего количества - а все остальные - "те что между"

# %%
data['one_metr'].hist(figsize=(5,5), range=(0,350000),xrot=45);

# %%
data['one_metr'].hist(figsize=(5,5),range=(30000,150000));

# %% [markdown]
# Пик приходится на показатели 90.000-100.000 рублей за метр, но дороже 170.000 за метро квартиры встречаются редко, дороже 210.000 - еще реже

# %%
data.boxplot(column='one_metr');

# %% [markdown]
# Верхний ус заканчивается как раз на 170.000

# %%
data['days_exposition'].describe()
# Out:
# count    19419.000000
# mean       174.595036
# std        212.686207
# min          1.000000
# 25%         44.000000
# 50%         92.000000
# 75%        222.000000
# max       1580.000000
# Name: days_exposition, dtype: float64

# %%
data.boxplot(column='days_exposition');

# %%
data['days_exposition'].hist();

# %%
data[data['days_exposition']>489]
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 2                10   5196000.0       56.00           2015-08-20      2
# 17                6   4180000.0       36.00           2016-09-09      1
# 23               11   2950000.0       32.00           2016-10-29      1
# 43               13   9330000.0       48.00           2017-01-10      2
# 61               18   7990000.0       74.00           2017-08-24      2
# ...             ...         ...         ...                  ...    ...
# 23664             5   9000000.0      110.00           2015-12-10      4
# 23672             5   3000000.0       30.80           2016-06-08      1
# 23675             8   3550000.0       39.50           2016-10-03      1
# 23691            11   9470000.0       72.90           2016-10-13      2
# 23697            13  11475000.0       76.75           2017-03-28      2
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  \
# 2                 NaN             5        34.30      4         False
# 17                NaN            17        16.50      7         False
# 23               2.60             9        17.70      9         False
# 43               3.00             4        28.00      4         False
# 61                NaN             4        43.00      4         False
# ...               ...           ...          ...    ...           ...
# 23664            3.36             7        64.60      5         False
# 23672             NaN             5        16.10      3         False
# 23675             NaN            16        19.00     13         False
# 23691            2.75            25        40.30      7         False
# 23697            3.00            17        46.05     12         False
#
#        is_studio  open_plan  kitchen_area  balcony    locality_name  \
# 2          False      False           8.3        0  Санкт-Петербург
# 17         False      False          11.0        1  Санкт-Петербург
# 23         False      False           6.1        0  Санкт-Петербург
# 43         False      False           7.5        0  Санкт-Петербург
# 61         False      False          20.0        0  Санкт-Петербург
# ...          ...        ...           ...      ...              ...
# 23664      False      False          15.8        0  Санкт-Петербург
# 23672      False      False           6.3        0  Санкт-Петербург
# 23675      False      False           8.5        0  Санкт-Петербург
# 23691      False      False          10.6        1  Санкт-Петербург
# 23697      False      False          23.3        2  Санкт-Петербург
#
#        airports_nearest  city_centers_nearest  parks_around_3000  \
# 2               21741.0               13933.0                1.0
# 17              33564.0               14616.0                0.0
# 23              15414.0               14211.0                2.0
# 43              15016.0               10822.0                0.0
# 61              22568.0                4288.0                1.0
# ...                 ...                   ...                ...
# 23664           26313.0                5016.0                3.0
# 23672           44614.0               14193.0                2.0
# 23675           25740.0               14951.0                0.0
# 23691           19424.0                4489.0                0.0
# 23697           39140.0               10364.0                2.0
#
#        parks_nearest  ponds_around_3000  ponds_nearest  days_exposition  \
# 2               90.0                2.0          574.0            558.0
# 17               NaN                1.0          859.0            571.0
# 23             517.0                1.0          190.0            615.0
# 43               NaN                1.0          492.0            763.0
# 61             363.0                0.0            NaN            609.0
# ...              ...                ...            ...              ...
# 23664          417.0                1.0          118.0            816.0
# 23672          258.0                0.0            NaN            808.0
# 23675            NaN                0.0            NaN            721.0
# 23691            NaN                1.0          806.0            519.0
# 23697          173.0                3.0          196.0            602.0
#
#       area_category  one_metr  km_from_city_center floor_type  year  month  \
# 2               big   92786.0                 14.0     Другой  2015      8
# 17            small  116111.0                 15.0     Другой  2016      9
# 23            small   92188.0                 14.0  Последний  2016     10
# 43           medium  194375.0                 11.0  Последний  2017      1
# 61          too_big  107973.0                  4.0  Последний  2017      8
# ...             ...       ...                  ...        ...   ...    ...
# 23664       too_big   81818.0                  5.0     Другой  2015     12
# 23672         small   97403.0                 14.0     Другой  2016      6
# 23675         small   89873.0                 15.0     Другой  2016     10
# 23691       too_big  129904.0                  4.0     Другой  2016     10
# 23697       too_big  149511.0                 10.0     Другой  2017      3
#
#        day
# 2        3
# 17       4
# 23       5
# 43       1
# 61       3
# ...    ...
# 23664    3
# 23672    2
# 23675    0
# 23691    3
# 23697    1
#
# [1598 rows x 29 columns]

# %% [markdown]
# В данном случае мы видим, что среднее время продажи - 92 дня, "нормальной" считается продажа в пределах от 44 дней до 222, 489 дней - порог нормально-долгого значения и аномально долгого, все что больше - считается уже "необычно долгой" продажей. Все что меньше 44 - соответственно - очень быстрой.

# %% [markdown]
# Также здесь достаточно много значений-выбросов - 1598 штук - 7% от числа всех объектов

# %%
pd.qcut(data['one_metr'], 5)
# Out:
# 0        (117778.0, 848485.0]
# 1          (70312.0, 87500.0]
# 2         (87500.0, 100121.8]
# 4         (87500.0, 100121.8]
# 5         (87500.0, 100121.8]
#                  ...
# 23693      (70312.0, 87500.0]
# 23695      (111.999, 70312.0]
# 23696      (111.999, 70312.0]
# 23697    (117778.0, 848485.0]
# 23698      (111.999, 70312.0]
# Name: one_metr, Length: 22259, dtype: category
# Categories (5, interval[float64, right]): [(111.999, 70312.0] < (70312.0, 87500.0] < (87500.0, 100121.8] < (100121.8, 117778.0] < (117778.0, 848485.0]]

# %%
df_an = data[['last_price','total_area','living_area','kitchen_area']]
pd.plotting.scatter_matrix(df_an, figsize=(10, 10), diagonal='kde');

# %% [markdown]
# Да этой матрице рассеивания показано (самая первая строчка) как общая площадь, площадь жилая и кухни (последние три графика первой строчки) влияют на рост цены:
#
# 1. Общая площадь:
#
#     Видно, что с увеличением общей площади объекта пропорционально растет цена объекта. Есть конечно и некоторые объекты, который в сравнении с объектами с такой же площадью имеют цену х2, но основная масса находится примерно в одном диапазоне.
#
#
# 2. Жилая площадь:
#
#     С жилой площадью примерно та же история, что и с общей площадью, потому что она зависит от общей площади => значения жилой площади и стоимости квартиры примерно такая же, как и зависимость между общей площадью и ценой объекта, разница лишь в том, что разброс жилой площади меньше - следовательно и разброс цен меньше.
#
#
# 3. Площадь кухни:
#
#     Немного другая история относительно плоащади кухни - при средних значениях наблюдается небольшой пик прироста цены.

# %%
data.hist(column='last_price');

# %%
pd.qcut(data['last_price'],3)
# Out:
# 0        (5500000.0, 53000000.0]
# 1         (12189.999, 3700000.0]
# 2         (3700000.0, 5500000.0]
# 4        (5500000.0, 53000000.0]
# 5         (12189.999, 3700000.0]
#                   ...
# 23693     (3700000.0, 5500000.0]
# 23695     (12189.999, 3700000.0]
# 23696     (12189.999, 3700000.0]
# 23697    (5500000.0, 53000000.0]
# 23698     (12189.999, 3700000.0]
# Name: last_price, Length: 22259, dtype: category
# Categories (3, interval[float64, right]): [(12189.999, 3700000.0] < (3700000.0, 5500000.0] < (5500000.0, 53000000.0]]

# %%
data.boxplot(column='last_price');

# %%
data['last_price'].describe()
# Out:
# count    2.225900e+04
# mean     5.272433e+06
# std      3.311203e+06
# min      1.219000e+04
# 25%      3.350000e+06
# 50%      4.500000e+06
# 75%      6.280000e+06
# max      5.300000e+07
# Name: last_price, dtype: float64

# %% [markdown]
# 10.675 - потолок верхнего уса, следовательно 10.675.000 - максимальная "нормальная" стоимость квартиры. Все что выше - считается "слишком дорогим" значением цены, имеет смысл посмотреть различия между нормальными, дешевыми и дорогими квартирами:

# %%
def flat_type(t):
    if t < 3350000:
        return 'low price'
    elif 3350000 < t < 6280000:
        return 'medium'
    else:
        return 'high'

# %%
data['type'] = data['last_price'].apply(flat_type)

# %% [markdown]
# Я поменяла еще в нескольких столбцах типы данных, и для сохранения изначальной таблицы, далее буду работать с её копией:

# %%
newdata = data.convert_dtypes().copy()
newdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22259 entries, 0 to 23698
# Data columns (total 30 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          22259 non-null  Int64
#  1   last_price            22259 non-null  Int64
#  2   total_area            22259 non-null  Float64
#  3   first_day_exposition  22259 non-null  datetime64[ns]
#  4   rooms                 22259 non-null  Int64
#  5   ceiling_height        13587 non-null  Float64
#  6   floors_total          22259 non-null  Int32
#  7   living_area           22259 non-null  Float64
#  8   floor                 22259 non-null  Int64
#  9   is_apartment          22259 non-null  boolean
#  10  is_studio             22259 non-null  boolean
#  11  open_plan             22259 non-null  boolean
#  12  kitchen_area          22259 non-null  Float64
#  13  balcony               22259 non-null  Int32
#  14  locality_name         22259 non-null  string
#  15  airports_nearest      22259 non-null  Float64
#  16  city_centers_nearest  22259 non-null  Float64
#  17  parks_around_3000     16808 non-null  Int64
#  18  parks_nearest         7196 non-null   Int64
#  19  ponds_around_3000     16808 non-null  Int64
#  20  ponds_nearest         8206 non-null   Int64
#  21  days_exposition       19419 non-null  Float64
#  22  area_category         22259 non-null  string
#  23  one_metr              22259 non-null  Int64
#  24  km_from_city_center   22259 non-null  Int64
#  25  floor_type            22259 non-null  string
#  26  year                  22259 non-null  Int64
#  27  month                 22259 non-null  Int64
#  28  day                   22259 non-null  Int64
#  29  type                  22259 non-null  string
# dtypes: Float64(7), Int32(2), Int64(13), boolean(3), datetime64[ns](1), string(4)
# memory usage: 5.2 MB

# %%
df8 = newdata.groupby('type').agg('median').copy()
df8['count'] = newdata.groupby('type')[['last_price']].count()
df8 = df8.sort_values('total_area')
df8
# Out:
#            total_images  last_price  total_area  rooms  ceiling_height  \
# type
# low price           8.0   2600000.0        37.4    1.0            2.55
# medium              9.5   4500000.0       47.35    2.0             2.6
# high               11.0   8150000.0        74.0    3.0             2.8
#
#            floors_total  living_area  floor  is_apartment  is_studio  \
# type
# low price           5.0         19.0    3.0           0.0        0.0
# medium              9.0         28.4    5.0           0.0        0.0
# high               10.0        42.75    5.0           0.0        0.0
#
#            open_plan  kitchen_area  balcony  airports_nearest  \
# type
# low price        0.0           7.0      0.0               0.0
# medium           0.0           8.7      0.0           25221.0
# high             0.0          12.0      0.0           26041.0
#
#            city_centers_nearest  parks_around_3000  parks_nearest  \
# type
# low price                   0.0                0.0          422.0
# medium                  13094.0                0.0          459.0
# high                    10458.0                1.0          459.0
#
#            ponds_around_3000  ponds_nearest  days_exposition  one_metr  \
# type
# low price                0.0          521.5             88.0   64978.0
# medium                   0.0          538.0             86.0   94386.0
# high                     1.0          486.0            111.0  117284.0
#
#            km_from_city_center    year  month  day  count
# type
# low price                  0.0  2017.0    6.0  3.0   5478
# medium                    13.0  2017.0    6.0  3.0  11108
# high                      10.0  2017.0    6.0  3.0   5673

# %% [markdown]
# В данной таблице видно, что цена растет сопоставимо общей площади, количеству комнат, расположению аэропорта и центра города поблизости. На стоимость слабо влияют наличие/отсутствие парков и водоёмов рядом, этаж здания и высота потолков.

# %%
df8_2 = data.pivot_table(index='total_area', values='last_price',aggfunc='median')
df8_2.plot(alpha=0.5);

# %% [markdown]
# По графику видно, что стоимость жилья увеличивается с ростом общей площади (конечно, имеют место быть и выбросы по значениям). Построим и для остальных площадей:

# %%
df8_3 = data.pivot_table(index='living_area', values='last_price',aggfunc='median')
df8_3.plot(alpha=0.5);

# %%
df8_4 = data.pivot_table(index='kitchen_area', values='last_price',aggfunc='median')
df8_4.plot(alpha=0.5);

# %% [markdown]
# С этими двумя графиками ситуация неоднозначная:
#
# 1. Касательно жилой площади, если отбросить кардиограмное настроение графика - цена постепенно увеличивается, однако слишком много "дерганий" графика, чтобы твержо утверждать, что между этими двумя показателями есть прямая зависимость.
#
# 2. Касательно графика зависимости между площадью кухни и общей площадью - ситуация сложнее, слишком большой разброс между показателями + в "конце" графика вообще непонятно что происходит, так что говорить о какой либо зависимости сложно.

# %%
newdata[['last_price','total_area','rooms','living_area','kitchen_area','airports_nearest','city_centers_nearest']].corr()
# Out:
#                       last_price  total_area     rooms  living_area  \
# last_price              1.000000    0.681588  0.382779     0.552568
# total_area              0.681588    1.000000  0.788510     0.909346
# rooms                   0.382779    0.788510  1.000000     0.872645
# living_area             0.552568    0.909346  0.872645     1.000000
# kitchen_area            0.538296    0.518340  0.136162     0.234937
# airports_nearest        0.225111    0.047214 -0.021439     0.006776
# city_centers_nearest    0.026589   -0.031615 -0.017841    -0.033737
#
#                       kitchen_area  airports_nearest  city_centers_nearest
# last_price                0.538296          0.225111              0.026589
# total_area                0.518340          0.047214             -0.031615
# rooms                     0.136162         -0.021439             -0.017841
# living_area               0.234937          0.006776             -0.033737
# kitchen_area              1.000000          0.092842             -0.037261
# airports_nearest          0.092842          1.000000              0.514786
# city_centers_nearest     -0.037261          0.514786              1.000000

# %%
import seaborn as sns
sns.heatmap(newdata[['last_price','total_area','rooms','living_area','kitchen_area','airports_nearest','city_centers_nearest']].corr());

# %% [markdown]
# Матрица корреляции и хитмэп (для наглядности) подтвердили зависимость между общей стоимостью и общей площадью (а также жилой площадью и площадью кухни). Однако так как количество  комнат достаточно тесно связано с жилой площадью - тогда возможно, что здесь взаимосвязь более сложная, и имеет место быть другой фактор, влияющий на итоговую стоимость объекта.

# %%
df_6 = newdata.pivot_table(index='rooms', values='last_price',aggfunc='median')
df_6.plot();

# %% [markdown]
# На графике видно, что чем больше количество комнат, тем больше цена. Однако количество комнат достаточно тесно связано с общей площадью квартиры.

# %%
df_9 = newdata.pivot_table(index='floor_type', values='last_price', aggfunc='median').sort_values('last_price')
df_9.plot();

# %% [markdown]
# Как видим, люди более интересуются "средними" этажами, квартиры на первом этаже имеют наименьшую среднюю стоимость

# %%
newdata[['last_price','day','month','year']].corr()
# Out:
#             last_price       day     month      year
# last_price    1.000000 -0.014996 -0.003387 -0.006737
# day          -0.014996  1.000000  0.012896 -0.003139
# month        -0.003387  0.012896  1.000000 -0.271004
# year         -0.006737 -0.003139 -0.271004  1.000000

# %%
newdata.groupby(['type','year'])[['last_price']].median()
# Out:
#                 last_price
# type      year
# high      2014  10487000.0
#           2015   8290000.0
#           2016   8100000.0
#           2017   8200000.0
#           2018   8040000.0
#           2019   8150000.0
# low price 2014   2649500.0
#           2015   2700000.0
#           2016   2700000.0
#           2017   2690000.0
#           2018   2570000.0
#           2019   2500000.0
# medium    2014   4600000.0
#           2015   4650000.0
#           2016   4399153.5
#           2017   4437500.0
#           2018   4500000.0
#           2019   4690000.0

# %%
df8_3 = newdata.pivot_table(index=['year'], values='last_price', aggfunc='median')
df8_3.plot();

# %% [markdown]
# В целом, как уже и оговаривалось выше, квартиры имели до 2016 года включительно к понижению средней стоимости, а с 2017 года - к увеличению

# %%
df8_3 = newdata[newdata['type']=='high'].pivot_table(index='year', values='last_price', aggfunc='median');
df8_3.plot();

# %% [markdown]
# Дорогие квартиры резко снизились в цене за 1 год и дальше держались относительно стабильно. С 2014 по 2018 год их стоимость упала практически на 24%.

# %%
df8_3 = newdata[newdata['type']=='medium'].pivot_table(index='year', values='last_price', aggfunc='median');
df8_3.plot();

# %% [markdown]
# У квартир средней ценовой категории наблюдается резкий надир в 2016 году, и повышение к 2019 году, но относильно показателей цены - значения колебались несильно - в пределах 5%.

# %%
df8_3 = newdata[newdata['type']=='low price'].pivot_table(index='year', values='last_price', aggfunc='median');
df8_3.plot();

# %% [markdown]
# Для квартир низкого бюджета наблюдается скачок в 2015 году - прирост цены на +-2%, а затем в 2018 году резкий спад практически на 5%.

# %%
newdata.groupby(['type','month'])[['last_price']].count()
# Out:
#                  last_price
# type      month
# high      1             369
#           2             642
#           3             600
#           4             614
#           5             281
#           6             413
#           7             389
#           8             419
#           9             485
#           10            494
#           11            560
#           12            407
# low price 1             354
#           2             638
#           3             609
#           4             501
#           5             293
#           6             451
#           7             381
#           8             417
#           9             446
#           10            474
#           11            518
#           12            396
# medium    1             678
#           2            1208
#           3            1240
#           4            1125
#           5             608
#           6             796
#           7             808
#           8             816
#           9             920
#           10           1039
#           11           1137
#           12            733

# %%
df8_4 = newdata.pivot_table(index='month', values='last_price', aggfunc='median');
df8_4.plot();

# %% [markdown]
# В апреле цена дороже, в июне - дешевле. Возможно это связано с временем года (период отпусков).

# %%
df8_4 = newdata[newdata['type']=='high'].pivot_table(index='month', values='last_price', aggfunc='median');
df8_4.plot();

# %% [markdown]
# Квартиры с высокой ценовой политикой - чаще всего публикуют объявления в Марте, Мае и Сентябре. Меньше всего - Февраль, Апрель, Июнь и Декабрь.

# %%
df8_4 = newdata[newdata['type']=='medium'].pivot_table(index='month', values='last_price', aggfunc='median');
df8_4.plot();

# %% [markdown]
# Пик - Апрель, надир - Юинь.

# %%
df8_4 = newdata[newdata['type']=='low price'].pivot_table(index='month', values='last_price', aggfunc='median');
df8_4.plot();

# %% [markdown]
# Пики - Февраль, Май, Август и Ноябрь. Надиры - Апрель, Июнь и Декабрь.

# %%
newdata.groupby(['type','day'])[['last_price']].count()
# Out:
#                last_price
# type      day
# high      0           846
#           1          1023
#           2           963
#           3          1047
#           4           961
#           5           455
#           6           378
# low price 0           809
#           1           953
#           2           918
#           3           998
#           4           917
#           5           475
#           6           408
# medium    0          1751
#           1          1965
#           2          1823
#           3          1955
#           4          1900
#           5           896
#           6           818

# %% [markdown]
# Как и предполагала в начале, имеет тенденция к выкладыванию объявлений на буднях - в середине недели, а к выходным - наоборот - к уменьшению.

# %%
df8_5 = newdata.pivot_table(index='day', values='last_price', aggfunc='median')
df8_5.plot();

# %% [markdown]
# Пик среди всех приходится на вторник - возможно, в понедельник возвращаются в рабочий ритм после выходных.

# %%
df8_4 = newdata[newdata['type']=='high'].pivot_table(index='day', values='last_price', aggfunc='median')
df8_4.plot();

# %% [markdown]
# Среди дорогих объектов реже всего выставляют новые объекты в пятницу и субботу.

# %%
df8_4 = newdata[newdata['type']=='medium'].pivot_table(index='day', values='last_price', aggfunc='median');
df8_4.plot();

# %% [markdown]
# По средним заметно проседает пятница, а пик приходится на вторник

# %%
df8_4 = newdata[newdata['type']=='low price'].pivot_table(index='day', values='last_price', aggfunc='median');
df8_4.plot();

# %% [markdown]
# У бюджетных вариантов самый сильный надир в субботу

# %%
df11 = data.groupby('locality_name')[['last_price','one_metr']].agg({'last_price':'count','one_metr':'median'}).copy()
df11 = df11.sort_values('last_price', ascending=False)
df11.head(10)
# Out:
#                    last_price  one_metr
# locality_name
# Санкт-Петербург         14446  103906.0
# поселок Мурино            552   86059.5
# поселок Шушары            435   76667.0
# Всеволожск                395   65789.0
# Пушкин                    346   99596.0
# Колпино                   336   74723.5
# поселок Парголово         326   91780.5
# Гатчина                   304   67861.0
# деревня Кудрово           298   91831.5
# Выборг                    227   58158.0

# %% [markdown]
# В таблице выше представлены средние цены по 10 городам с наибольшим количеством объявлений.

# %%
df11.sort_values('one_metr', ascending=False)
# Out:
#                        last_price  one_metr
# locality_name
# Санкт-Петербург             14446  103906.0
# Зеленогорск                    23  103333.0
# Сестрорецк                    168  100493.0
# Кудрово                       171  100000.0
# Пушкин                        346   99596.0
# ...                           ...       ...
# поселок Совхозный               2   12629.5
# деревня Выскатка                2   12335.5
# деревня Вахнова Кара            1   11688.0
# поселок станции Свирь           2   11481.5
# деревня Старополье              3   11000.0
#
# [328 rows x 2 columns]

# %% [markdown]
# В данной таблице представлены "самые дорогие" и "самые бюджетные" районы. Неожиданно, что Санкт-Петербург занимает лишь 2е место, курортный город "Зеленогорск" его обогнал.

# %%
df_spb = newdata[newdata['locality_name'] == 'Санкт-Петербург']
df_spb
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 0                20    13000000       108.0           2019-03-07      3
# 2                10     5196000        56.0           2015-08-20      2
# 4                 2    10000000       100.0           2018-06-19      2
# 7                 5     7915000        71.6           2019-04-18      2
# 9                18     5400000        61.0           2017-02-26      3
# ...             ...         ...         ...                  ...    ...
# 23688            19     9200000       101.0           2019-04-01      3
# 23689            13     3550000        35.3           2018-02-28      1
# 23690             3     5500000        52.0           2018-07-19      2
# 23691            11     9470000        72.9           2016-10-13      2
# 23697            13    11475000       76.75           2017-03-28      2
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  \
# 0                 2.7            16         51.0      8         False
# 2                <NA>             5         34.3      4         False
# 4                3.03            14         32.0     13         False
# 7                <NA>            24        42.96     22         False
# 9                 2.5             9         43.6      7         False
# ...               ...           ...          ...    ...           ...
# 23688            3.05            15         63.0     12         False
# 23689            2.86            15         16.3      4         False
# 23690            <NA>             5         31.0      2         False
# 23691            2.75            25         40.3      7         False
# 23697             3.0            17        46.05     12         False
#
#        is_studio  open_plan  kitchen_area  balcony    locality_name  \
# 0          False      False          25.0        0  Санкт-Петербург
# 2          False      False           8.3        0  Санкт-Петербург
# 4          False      False          41.0        0  Санкт-Петербург
# 7          False      False          18.9        2  Санкт-Петербург
# 9          False      False           6.5        2  Санкт-Петербург
# ...          ...        ...           ...      ...              ...
# 23688      False      False          15.0        0  Санкт-Петербург
# 23689      False      False           9.1        2  Санкт-Петербург
# 23690      False      False           6.0        0  Санкт-Петербург
# 23691      False      False          10.6        1  Санкт-Петербург
# 23697      False      False          23.3        2  Санкт-Петербург
#
#        airports_nearest  city_centers_nearest  parks_around_3000  \
# 0               18863.0               16028.0                  1
# 2               21741.0               13933.0                  1
# 4               31856.0                8098.0                  2
# 7               23982.0               11634.0                  0
# 9               50898.0               15008.0                  0
# ...                 ...                   ...                ...
# 23688           15632.0               14428.0                  0
# 23689           17284.0               16081.0                  1
# 23690           20151.0                6263.0                  1
# 23691           19424.0                4489.0                  0
# 23697           39140.0               10364.0                  2
#
#        parks_nearest  ponds_around_3000  ponds_nearest  days_exposition  \
# 0                482                  2            755             <NA>
# 2                 90                  2            574            558.0
# 4                112                  1             48            121.0
# 7               <NA>                  0           <NA>             <NA>
# 9               <NA>                  0           <NA>            289.0
# ...              ...                ...            ...              ...
# 23688           <NA>                  0           <NA>             23.0
# 23689            353                  2            652             29.0
# 23690            300                  0           <NA>             15.0
# 23691           <NA>                  1            806            519.0
# 23697            173                  3            196            602.0
#
#       area_category  one_metr  km_from_city_center floor_type  year  month  \
# 0           too_big    120370                   16     Другой  2019      3
# 2               big     92786                   14     Другой  2015      8
# 4           too_big    100000                    8     Другой  2018      6
# 7           too_big    110545                   12     Другой  2019      4
# 9               big     88525                   15     Другой  2017      2
# ...             ...       ...                  ...        ...   ...    ...
# 23688       too_big     91089                   14     Другой  2019      4
# 23689         small    100567                   16     Другой  2018      2
# 23690       too_big    105769                    6     Другой  2018      7
# 23691       too_big    129904                    4     Другой  2016     10
# 23697       too_big    149511                   10     Другой  2017      3
#
#        day    type
# 0        3    high
# 2        3  medium
# 4        1    high
# 7        3    high
# 9        6  medium
# ...    ...     ...
# 23688    0    high
# 23689    2  medium
# 23690    3  medium
# 23691    3    high
# 23697    1    high
#
# [14446 rows x 30 columns]

# %%
df_spb['m_km'] = df_spb['last_price']/df_spb['km_from_city_center']
df_spb
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 0                20    13000000       108.0           2019-03-07      3
# 2                10     5196000        56.0           2015-08-20      2
# 4                 2    10000000       100.0           2018-06-19      2
# 7                 5     7915000        71.6           2019-04-18      2
# 9                18     5400000        61.0           2017-02-26      3
# ...             ...         ...         ...                  ...    ...
# 23688            19     9200000       101.0           2019-04-01      3
# 23689            13     3550000        35.3           2018-02-28      1
# 23690             3     5500000        52.0           2018-07-19      2
# 23691            11     9470000        72.9           2016-10-13      2
# 23697            13    11475000       76.75           2017-03-28      2
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  \
# 0                 2.7            16         51.0      8         False
# 2                <NA>             5         34.3      4         False
# 4                3.03            14         32.0     13         False
# 7                <NA>            24        42.96     22         False
# 9                 2.5             9         43.6      7         False
# ...               ...           ...          ...    ...           ...
# 23688            3.05            15         63.0     12         False
# 23689            2.86            15         16.3      4         False
# 23690            <NA>             5         31.0      2         False
# 23691            2.75            25         40.3      7         False
# 23697             3.0            17        46.05     12         False
#
#        is_studio  open_plan  kitchen_area  balcony    locality_name  \
# 0          False      False          25.0        0  Санкт-Петербург
# 2          False      False           8.3        0  Санкт-Петербург
# 4          False      False          41.0        0  Санкт-Петербург
# 7          False      False          18.9        2  Санкт-Петербург
# 9          False      False           6.5        2  Санкт-Петербург
# ...          ...        ...           ...      ...              ...
# 23688      False      False          15.0        0  Санкт-Петербург
# 23689      False      False           9.1        2  Санкт-Петербург
# 23690      False      False           6.0        0  Санкт-Петербург
# 23691      False      False          10.6        1  Санкт-Петербург
# 23697      False      False          23.3        2  Санкт-Петербург
#
#        airports_nearest  city_centers_nearest  parks_around_3000  \
# 0               18863.0               16028.0                  1
# 2               21741.0               13933.0                  1
# 4               31856.0                8098.0                  2
# 7               23982.0               11634.0                  0
# 9               50898.0               15008.0                  0
# ...                 ...                   ...                ...
# 23688           15632.0               14428.0                  0
# 23689           17284.0               16081.0                  1
# 23690           20151.0                6263.0                  1
# 23691           19424.0                4489.0                  0
# 23697           39140.0               10364.0                  2
#
#        parks_nearest  ponds_around_3000  ponds_nearest  days_exposition  \
# 0                482                  2            755             <NA>
# 2                 90                  2            574            558.0
# 4                112                  1             48            121.0
# 7               <NA>                  0           <NA>             <NA>
# 9               <NA>                  0           <NA>            289.0
# ...              ...                ...            ...              ...
# 23688           <NA>                  0           <NA>             23.0
# 23689            353                  2            652             29.0
# 23690            300                  0           <NA>             15.0
# 23691           <NA>                  1            806            519.0
# 23697            173                  3            196            602.0
#
#       area_category  one_metr  km_from_city_center floor_type  year  month  \
# 0           too_big    120370                   16     Другой  2019      3
# 2               big     92786                   14     Другой  2015      8
# 4           too_big    100000                    8     Другой  2018      6
# 7           too_big    110545                   12     Другой  2019      4
# 9               big     88525                   15     Другой  2017      2
# ...             ...       ...                  ...        ...   ...    ...
# 23688       too_big     91089                   14     Другой  2019      4
# 23689         small    100567                   16     Другой  2018      2
# 23690       too_big    105769                    6     Другой  2018      7
# 23691       too_big    129904                    4     Другой  2016     10
# 23697       too_big    149511                   10     Другой  2017      3
#
#        day    type           m_km
# 0        3    high       812500.0
# 2        3  medium  371142.857143
# 4        1    high      1250000.0
# 7        3    high  659583.333333
# 9        6  medium       360000.0
# ...    ...     ...            ...
# 23688    0    high  657142.857143
# 23689    2  medium       221875.0
# 23690    3  medium  916666.666667
# 23691    3    high      2367500.0
# 23697    1    high      1147500.0
#
# [14446 rows x 31 columns]

# %% [markdown]
# Немного не понимаю, что значит "средняя цена каждого километра"

# %%
df_spb[['last_price','km_from_city_center']].corr()
# Out:
#                      last_price  km_from_city_center
# last_price             1.000000            -0.379717
# km_from_city_center   -0.379717             1.000000

# %%
df_spb[df_spb['km_from_city_center']!=0.0].plot(x='km_from_city_center', y='last_price', kind='scatter', alpha=0.5);

# %% [markdown]
# По матрице корреляции видно и графику, что зависимость между километражем до центра и стоимость обратная, однако нельзя говорить о сильной взаимосвязи, тк коеффициент корреляции = -0.37.

# %%
spb_km = df_spb.pivot_table(index='km_from_city_center', values='m_km',aggfunc='median')
spb_km
# Out:
#                                m_km
# km_from_city_center
# 0                               inf
# 1                         9200000.0
# 2                         4430000.0
# 3                         2521000.0
# 4                         1987500.0
# 5                         1600000.0
# 6                    1266666.666667
# 7                     971428.571429
# 8                          834375.0
# 9                     577777.777778
# 10                         495000.0
# 11                         450000.0
# 12                    408333.333333
# 13                         400000.0
# 14                    342857.142857
# 15                         320000.0
# 16                         296875.0
# 17                    267647.058824
# 18                    236111.111111
# 19                    236842.105263
# 20                         277500.0
# 21                    250225.619048
# 22                    222386.363636
# 23                    191304.347826
# 24                         145000.0
# 25                        151795.24
# 26                    129038.461538
# 27                    307407.407407
# 28                    178214.285714
# 29                    156379.310345

# %%
spb_km.plot(grid = True, title = 'Заголовок');

# %% [markdown]
# На графике показана зависимость стоимости от удаленности от центра квартир Питера. Соответственно, чем дальше, тем меньше стоит объект

# %% [markdown]
# ### Общий вывод

# %% [markdown]
# В начале работы мы ставили целью определить ценообразующие факторы разных объектов Санкт-Петербурга и Ленинградской области.
#
# Проведя анализ исходных данных, подготовив их для исследования, заполнив пропуски и убрав выбивающиеся значения, мы изучили вопрос с разных сторон и сделали вывод, что самое большое влияние на стоимость оказали общая площадь объекта, а также год публикации (в разные года были разные тенденции).
#
# Также прослеживается прямая зависимость между стоимостью и удаленностью от центра города (чем дальше - тем дешевле), наличием/отсутствием аэропорта (наличие аэропорта в городе - больше +, чем -), количеством комнат (количество комнат в целом растет пропорционально общей площади помещения), а также площадью жилой и кухни (аналогично с количеством комнат).
#
# Зависимость между ценой объекта и расстоянием до центра города можно объяснить следующим образом:
#
# Базовая стоимость объекта складывается из понятий общей площади, количества комнат, расположения (какой это город и есть ли аэропорт), при том, чем меньше расстояние от центра города, тем выше стоимость.

# %% [markdown]
# **Чек-лист готовности проекта**
#
# - [x]  открыт файл
# - [x]  файлы изучены (выведены первые строки, метод `info()`, гистограммы и т.д.)
# - [x]  определены пропущенные значения
# - [x]  заполнены пропущенные значения там, где это возможно
# - [x]  есть пояснение, какие пропущенные значения обнаружены
# - [x]  изменены типы данных
# - [x]  есть пояснение, в каких столбцах изменены типы и почему
# - [x]  устранены неявные дубликаты в названиях населённых пунктов
# - [x]  устранены редкие и выбивающиеся значения (аномалии) во всех столбцах
# - [x]  посчитано и добавлено в таблицу: цена одного квадратного метра
# - [x]  посчитано и добавлено в таблицу: день публикации объявления (0 - понедельник, 1 - вторник и т.д.)
# - [x]  посчитано и добавлено в таблицу: месяц публикации объявления
# - [x]  посчитано и добавлено в таблицу: год публикации объявления
# - [x]  посчитано и добавлено в таблицу: тип этажа квартиры (значения — «первый», «последний», «другой»)
# - [x]  посчитано и добавлено в таблицу: расстояние в км до центра города
# - [x]  изучены и описаны следующие параметры:
#         - общая площадь;
#         - жилая площадь;
#         - площадь кухни;
#         - цена объекта;
#         - количество комнат;
#         - высота потолков;
#         - этаж квартиры;
#         - тип этажа квартиры («первый», «последний», «другой»);
#         - общее количество этажей в доме;
#         - расстояние до центра города в метрах;
#         - расстояние до ближайшего аэропорта;
#         - расстояние до ближайшего парка;
#         - день и месяц публикации объявления
# - [x]  построены гистограммы для каждого параметра
# - [x]  выполнено задание: "Изучите, как быстро продавались квартиры (столбец days_exposition). Этот параметр показывает, сколько дней «висело» каждое объявление.
#     - Постройте гистограмму.
#     - Посчитайте среднее и медиану.
#     - В ячейке типа markdown опишите, сколько обычно занимает продажа. Какие продажи можно считать быстрыми, а какие — необычно долгими?"
# - [x]  выполнено задание: "Какие факторы больше всего влияют на общую (полную) стоимость объекта? Постройте графики, которые покажут зависимость цены от указанных ниже параметров. Для подготовки данных перед визуализацией вы можете использовать сводные таблицы."
#         - общей площади;
#         - жилой площади;
#         - площади кухни;
#         - количество комнат;
#         - типа этажа, на котором расположена квартира (первый, последний, другой);
#         - даты размещения (день недели, месяц, год);
# - [x]  выполнено задание: "Посчитайте среднюю цену одного квадратного метра в 10 населённых пунктах с наибольшим числом объявлений. Выделите населённые пункты с самой высокой и низкой стоимостью квадратного метра. Эти данные можно найти по имени в столбце `locality_name`."
# - [x]  выполнено задание: "Ранее вы посчитали расстояние до центра в километрах. Теперь выделите квартиры в Санкт-Петербурге с помощью столбца `locality_name` и вычислите среднюю цену каждого километра. Опишите, как стоимость объектов зависит от расстояния до центра города."
# - [x]  в каждом этапе есть промежуточные выводы
# - [x]  есть общий вывод
