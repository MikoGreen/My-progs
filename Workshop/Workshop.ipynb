# %% [markdown]
# # Мастерская. Проект.
#
# ## Заказчик: *GoProtect*
#
# ### Задача: сервис  “Мой Чемпион” помогает спортивным школам фигурного катания, тренерам мониторить результаты своих подопечных и планировать дальнейшее развитие спортсменов.
#
# #### Этап 1. Исследование данных

# %%
import pandas as pd
import numpy as np
import warnings 
warnings.filterwarnings("ignore")

from sklearn.model_selection import train_test_split
from sentence_transformers.util import semantic_search
from sentence_transformers import SentenceTransformer, InputExample, losses
from sentence_transformers.trainer import SentenceTransformerTrainer
from torch.utils.data import DataLoader
import nlpaug.augmenter.char as nac

# %%
df_rough = pd.read_csv('C:/Users/Home/Downloads/data_02_match_school/Примерное_написание.csv')
df_clean = pd.read_csv('C:/Users/Home/Downloads/data_02_match_school/Школы.csv')

# %%
# сбор данных о датафрейме:
def data_info(data):
    print(f'''
    ----------------------------------------
    Первые строки датафрейма:
    ----------------------------------------''')
    display(data.head())
    print(f'''
    ----------------------------------------
    Последние строки датафрейма:
    ----------------------------------------''')
    display(data.tail())
    print(f'''
    ----------------------------------------
    Общая информация:
    ----------------------------------------''')
    print(data.info())
    print(f'''
    ----------------------------------------
    Дупликаты:
    ----------------------------------------''')
    print(data.duplicated().sum())
    print(f'''
    ----------------------------------------
    Пропуски:
    ----------------------------------------''')
    display(round(data.isna().sum(),))

# %%
data_info(df_rough)
# Out:
#     ----------------------------------------
#     Первые строки датафрейма:
#     ----------------------------------------
#    school_id                                               name
# 0       1836                                       ООО "Триумф"
# 1       1836                                Москва, СК "Триумф"
# 2        610                             СШОР "Надежда Губернии
# 3        610  Саратовская область, ГБУСО "СШОР "Надежда Губе...
# 4        609                                     "СШ "Гвоздика"
#     ----------------------------------------
#     Последние строки датафрейма:
#     ----------------------------------------
#      school_id                                               name
# 890          3             Республика Татарстан, СШОР ФСО Авиатор
# 891          3             СШОР ФСО Авиатор, Республика Татарстан
# 892          3  Республика Татарстан, МБУ ДО СШОР «ФСО "Авиатор"»
# 893          2                                ЯНАО, СШ "Авангард"
# 894          1                  Московская область, СШ "Авангард"
#     ----------------------------------------
#     Общая информация:
#     ----------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 895 entries, 0 to 894
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   school_id  895 non-null    int64
#  1   name       895 non-null    object
# dtypes: int64(1), object(1)
# memory usage: 14.1+ KB
# None
#
#     ----------------------------------------
#     Дупликаты:
#     ----------------------------------------
# 0
#
#     ----------------------------------------
#     Пропуски:
#     ----------------------------------------
# school_id    0
# name         0
# dtype: int64

# %% [markdown]
# В таблице имеются 2 колокни:
# - school_id - id школы
# - name - собственно название, как оно предположительно будет вбиваться в базу
#
# Датасет небольшой, всего 895 строк, явных дупликатов нет.

# %%
data_info(df_clean)
# Out:
#     ----------------------------------------
#     Первые строки датафрейма:
#     ----------------------------------------
#    school_id                  name                region
# 0          1              Авангард    Московская область
# 1          2              Авангард     Ямало-Ненецкий АО
# 2          3               Авиатор  Республика Татарстан
# 3          4                Аврора       Санкт-Петербург
# 4          5  Ice Dream / Айс Дрим       Санкт-Петербург
#     ----------------------------------------
#     Последние строки датафрейма:
#     ----------------------------------------
#      school_id                    name                 region
# 301        305                Прогресс         Алтайский край
# 302        609          "СШ "Гвоздика"  Удмуртская республика
# 303        610  СШОР "Надежда Губернии    Саратовская область
# 304        611           КФК «Айсберг»          Пермский край
# 305       1836            ООО "Триумф"                 Москва
#     ----------------------------------------
#     Общая информация:
#     ----------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 306 entries, 0 to 305
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   school_id  306 non-null    int64
#  1   name       306 non-null    object
#  2   region     306 non-null    object
# dtypes: int64(1), object(2)
# memory usage: 7.3+ KB
# None
#
#     ----------------------------------------
#     Дупликаты:
#     ----------------------------------------
# 0
#
#     ----------------------------------------
#     Пропуски:
#     ----------------------------------------
# school_id    0
# name         0
# region       0
# dtype: int64

# %% [markdown]
# Второй датасет из 306 школ, явных дупликатов нет.
#
# Видим, что обычно, школы пишутся с округом, в котором находятся, поэтому первым делом нужно будет и в *эталонных* названиях их объединить.
#
# Так как школ у нас достаточно немного, необходимо продумать возможность переобучения при обучении на сырых данных. Скорее всего, произойдет чрезмерная подгонка модели под датасет и при новых данных она будет выдавать точность сильно ниже. Поэтому, работать мы будет с помощью аугментации - добавим в "чистый" датасет грязных данных и обучим модель на них.

# %%
df_clean.sort_values('region').iloc[50:100, :]
# Out:
#      school_id                                     name                 region
# 209        210                                 СШОР № 2     Курганская область
# 17          18                                    Арена        Курская область
# 34          35                                    ВСШОР  Ленинградская область
# 183        184                                  СШ № 11       Липецкая область
# 112        113                           Новочебоксарск                 Москва
# 74          75                         Конек Чайковской                 Москва
# 135        136                                ПроСинхро                 Москва
# 105        106                                  Москвич                 Москва
# 81          82                                  Легенда                 Москва
# 103        104                              МОСГОРСПОРТ                 Москва
# 101        102                                    Мечта                 Москва
# 137        138                                  Прусова                 Москва
# 100        101                               Медведково                 Москва
# 118        119                                    Олимп                 Москва
# 305       1836                             ООО "Триумф"                 Москва
# 159        160                                Созвездие                 Москва
# 299        303                           ООО "СетПоинт"                 Москва
# 290        294         ГБУ "МосСпортОбъект" ЛЦ "Звезда"                 Москва
# 289        293               АНО Лига фигурного катания                 Москва
# 260        262                                Южный Лед                 Москва
# 9           10  Академия синхронного катания на коньках                 Москва
# 251        252                       ЦСКА им. С.А. Жука                 Москва
# 250        251                                     ЦСКА                 Москва
# 14          15                          Ангелы Плющенко                 Москва
# 246        247                    Центр развития спорта                 Москва
# 243        244                              Хрустальный                 Москва
# 19          20                  Армия фигурного катания                 Москва
# 210        211                                 СШОР № 2                 Москва
# 27          28                              Вдохновение                 Москва
# 33          34                                  Волкова                 Москва
# 95          96                                    МАФКК                 Москва
# 170        171                                  Столица                 Москва
# 160        161                               Сокольники                 Москва
# 147        148                                    Салют     Московская область
# 226        227                                  УОР № 1     Московская область
# 247        248              Центр спортивных технологий     Московская область
# 115        116                                 Одинцово     Московская область
# 128        129                                Пахомовой     Московская область
# 297        301                    МБУ "ЦФКиС г. Лобня"      Московская область
# 109        110                             Наши надежды     Московская область
# 91          92                                  Ляпкина     Московская область
# 0            1                                 Авангард     Московская область
# 41          42                                  Давыдов     Московская область
# 90          91                                Лыткарино     Московская область
# 69          70                          Клин спортивный     Московская область
# 20          21                  Армия фигурного катания     Московская область
# 15          16                          Ангелы Плющенко     Московская область
# 13          14                        Альберта Демченко     Московская область
# 186        187                                  СШ № 6      Мурманская область
# 185        186                                   СШ № 6     Мурманская область

# %% [markdown]
# На данный момент, есть уже несколько неявных дупликатов. Чтобы не сопоставлять названия школ, не гадать, совпадают ли они, неплохо было бы добавить колонку государственной регистрации школ (по типу ИНН или подобного), чтобы не возникало путаницы. На данный момент, имеется датасет без неявных дупликатов, поэтому обучать модели буду на нем:

# %%
df_clean = pd.read_csv('C:/Users/Home/Downloads/data_02_match_school/reference_schools.csv', index_col=0).reset_index(drop=True)

# %%
data_info(df_clean)
# Out:
#     ----------------------------------------
#     Первые строки датафрейма:
#     ----------------------------------------
#    school_id                  name                region
# 0          1              Авангард    Московская область
# 1          2              Авангард     Ямало-Ненецкий АО
# 2          3               Авиатор  Республика Татарстан
# 3          4                Аврора       Санкт-Петербург
# 4          5  Ice Dream / Айс Дрим       Санкт-Петербург
#     ----------------------------------------
#     Последние строки датафрейма:
#     ----------------------------------------
#      school_id                    name                 region
# 283        305                Прогресс         Алтайский край
# 284        609          "СШ "Гвоздика"  Удмуртская республика
# 285        610  СШОР "Надежда Губернии    Саратовская область
# 286        611           КФК «Айсберг»          Пермский край
# 287       1836            ООО "Триумф"                 Москва
#     ----------------------------------------
#     Общая информация:
#     ----------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 288 entries, 0 to 287
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   school_id  288 non-null    int64
#  1   name       288 non-null    object
#  2   region     288 non-null    object
# dtypes: int64(1), object(2)
# memory usage: 6.9+ KB
# None
#
#     ----------------------------------------
#     Дупликаты:
#     ----------------------------------------
# 0
#
#     ----------------------------------------
#     Пропуски:
#     ----------------------------------------
# school_id    0
# name         0
# region       0
# dtype: int64

# %%
df_clean['name'] = (df_clean.name.replace('No',' ', regex=True)
                    .replace('№',' ',regex=True)
                    .replace(r'^А-Яа-яЁЙ\w\s', ' ', regex=True)
                    .replace('\s+', ' ', regex=True))

# %% [markdown]
# #### Этап 2. Аугментация.

# %%
df_clean['united'] = df_clean['name'] + ' по ' + df_clean['region']
display(df_clean)
df = df_clean[['school_id','united']]
df
# Out:
#      school_id                    name                 region  \
# 0            1                Авангард     Московская область
# 1            2                Авангард      Ямало-Ненецкий АО
# 2            3                 Авиатор   Республика Татарстан
# 3            4                  Аврора        Санкт-Петербург
# 4            5    Ice Dream / Айс Дрим        Санкт-Петербург
# ..         ...                     ...                    ...
# 283        305                Прогресс         Алтайский край
# 284        609          "СШ "Гвоздика"  Удмуртская республика
# 285        610  СШОР "Надежда Губернии    Саратовская область
# 286        611           КФК «Айсберг»          Пермский край
# 287       1836            ООО "Триумф"                 Москва
#
#                                             united
# 0                   Авангард по Московская область
# 1                    Авангард по Ямало-Ненецкий АО
# 2                  Авиатор по Республика Татарстан
# 3                        Аврора по Санкт-Петербург
# 4          Ice Dream / Айс Дрим по Санкт-Петербург
# ..                                             ...
# 283                     Прогресс по Алтайский край
# 284        "СШ "Гвоздика" по Удмуртская республика
# 285  СШОР "Надежда Губернии по Саратовская область
# 286                 КФК «Айсберг» по Пермский край
# 287                         ООО "Триумф" по Москва
#
# [288 rows x 4 columns]
#      school_id                                         united
# 0            1                 Авангард по Московская область
# 1            2                  Авангард по Ямало-Ненецкий АО
# 2            3                Авиатор по Республика Татарстан
# 3            4                      Аврора по Санкт-Петербург
# 4            5        Ice Dream / Айс Дрим по Санкт-Петербург
# ..         ...                                            ...
# 283        305                     Прогресс по Алтайский край
# 284        609        "СШ "Гвоздика" по Удмуртская республика
# 285        610  СШОР "Надежда Губернии по Саратовская область
# 286        611                 КФК «Айсберг» по Пермский край
# 287       1836                         ООО "Триумф" по Москва
#
# [288 rows x 2 columns]

# %% [markdown]
# В первую очередь будем тестировать *"нейросеть из коробки"* - SentenceTransformer. Для этого, сделаем аугментацию данных, ибо данных достаточно мало самих по себе. Будем увеличивать и изменять эталонный датасет, по которому и будем обучать модель.
#
# Далее было принято решение сделать 2 самых частых возможных варианта опечаток в тексте:
# - когда случайно была введена дополнительная буква (включая оба регистра)
# - когда случайно буквы были поменяны местами

# %%
aug = nac.RandomCharAug(candidates=['А','Б','В','Г','Д','Е','Ё','Ж','З','И',
                                    'Й','К','Л','М','Н','О','П','Р','С','Т',
                                    'У','Ф','Х','Ц','Ч','Ш','Щ','Ъ','Ы','Ь',
                                    'Э','Ю','Я','а','б','в','г','д','е','ё',
                                    'ж','з','и','й','к','л','м','н','о','п',
                                    'р','с','т','у','ф','х','ц','ч','ш','щ',
                                    'ъ','ы','ь','э','ю','я'],
                       action = 'insert', aug_char_max=2, aug_word_max=2)

df['insert'] = df.united.transform(lambda x: aug.augment(x, n=4))
df = df.explode('insert')
aug = nac.RandomCharAug(candidates=['А','Б','В','Г','Д','Е','Ё','Ж','З','И',
                                    'Й','К','Л','М','Н','О','П','Р','С','Т',
                                    'У','Ф','Х','Ц','Ч','Ш','Щ','Ъ','Ы','Ь',
                                    'Э','Ю','Я','а','б','в','г','д','е','ё',
                                    'ж','з','и','й','к','л','м','н','о','п',
                                    'р','с','т','у','ф','х','ц','ч','ш','щ',
                                    'ъ','ы','ь','э','ю','я'],
                       action = 'swap', swap_mode = 'adjacent', aug_char_max=3)
       
df['aug'] = df['insert'].transform(lambda x: aug.augment(x, n=4))
df = df.explode('aug').reset_index(drop=True).drop('insert',axis=1)
df.head(25)
# Out:
#     school_id                          united  \
# 0           1  Авангард по Московская область
# 1           1  Авангард по Московская область
# 2           1  Авангард по Московская область
# 3           1  Авангард по Московская область
# 4           1  Авангард по Московская область
# 5           1  Авангард по Московская область
# 6           1  Авангард по Московская область
# 7           1  Авангард по Московская область
# 8           1  Авангард по Московская область
# 9           1  Авангард по Московская область
# 10          1  Авангард по Московская область
# 11          1  Авангард по Московская область
# 12          1  Авангард по Московская область
# 13          1  Авангард по Московская область
# 14          1  Авангард по Московская область
# 15          1  Авангард по Московская область
# 16          2   Авангард по Ямало-Ненецкий АО
# 17          2   Авангард по Ямало-Ненецкий АО
# 18          2   Авангард по Ямало-Ненецкий АО
# 19          2   Авангард по Ямало-Ненецкий АО
# 20          2   Авангард по Ямало-Ненецкий АО
# 21          2   Авангард по Ямало-Ненецкий АО
# 22          2   Авангард по Ямало-Ненецкий АО
# 23          2   Авангард по Ямало-Ненецкий АО
# 24          2   Авангард по Ямало-Ненецкий АО
#
#                                     aug
# 0    АовангОард по ЙМоскьовкяса обалсть
# 1    АонваоГард по ЙМоскьовская боалсьт
# 2    АовангОард по МЙокьсовская облсьат
# 3    АоавнгОдар по ЙМоскьовская обалсть
# 4    Авагандр по ХМоскобвская обласатНь
# 5    Авангард по МХоскбовскяа олбааснТь
# 6    Аавгнадр по ХМоскобвская боалсатНь
# 7    Ваанград по ХМоскобвская олбаастЬн
# 8    Аавгнадр по чМосковРская иболаЧсть
# 9    Ваангард по чМосквоСркяа иоблаЧсть
# 10   Авнагдар по мЧоксовРсакя иоблаЧсть
# 11   Авангард по чМосвкоРсакя ибоалСчть
# 12   цАвфангард по Мсококвсая обсЛваСть
# 13   аВцфанград по Московская олбАссТвь
# 14   цАавфнгадр по Омскосвкяа облСасВть
# 15   цАфвагнрад по Осмковскяа облСасВть
# 16  Авнагдар по ЯумЯало - НГенецкиЙи АО
# 17  Ваанагдр по ЯумЯало - НЕгенкциИй АО
# 18  Аавнгард по ЯумЯало - НЕгнцекиИй АО
# 19  Авангард по ЯумЯлао - НГенекциИй АО
# 20  Аанвагрд по еЯммало - ЕненцФкбИй АО
# 21  Аванагрд по еЯммало - НенецФкбИй АО
# 22  Анвгаард по яЕммлао - НенецФкиБй АО
# 23  Ваангдар по еЯммало - НнеецФикЙб АО
# 24  Амшвнгаард по УЯаммОл - Ненецкий АО

# %%
df.shape
# Out:
# (4608, 3)

# %% [markdown]
# В итоге, у нас из **300+** строк получилось ***4600***. Получилось по 15 вариантов *различного* написания для одной *эталонной* школы.

# %%
dfff = df.copy()

# %% [markdown]
# #### Этап 3. Обучение модели.

# %% [markdown]
# Пробуем LaBSE:

# %%
model = SentenceTransformer('sentence-transformers/LaBSE')

# %%
corpus = model.encode(df_clean.united.values)

# %%
query = model.encode(df.aug.values)

# %%
search_res = semantic_search(query, corpus, top_k=1)

# %%
df['candidates_ind'] = [x[0]['corpus_id'] for x in search_res]
df['candidate_names'] = df.candidates_ind.transform(lambda x: df_clean.united.values[x])
df['candidate_id'] = df.candidates_ind.transform(lambda x: df_clean.school_id.values[x])
df.head(10)
# Out:
#    school_id                          united  \
# 0          1  Авангард по Московская область
# 1          1  Авангард по Московская область
# 2          1  Авангард по Московская область
# 3          1  Авангард по Московская область
# 4          1  Авангард по Московская область
# 5          1  Авангард по Московская область
# 6          1  Авангард по Московская область
# 7          1  Авангард по Московская область
# 8          1  Авангард по Московская область
# 9          1  Авангард по Московская область
#
#                                   aug  candidates_ind  \
# 0  АовангОард по ЙМоскьовкяса обалсть               0
# 1  АонваоГард по ЙМоскьовская боалсьт               0
# 2  АовангОард по МЙокьсовская облсьат               0
# 3  АоавнгОдар по ЙМоскьовская обалсть               0
# 4  Авагандр по ХМоскобвская обласатНь               0
# 5  Авангард по МХоскбовскяа олбааснТь               0
# 6  Аавгнадр по ХМоскобвская боалсатНь             124
# 7  Ваанград по ХМоскобвская олбаастЬн               0
# 8  Аавгнадр по чМосковРская иболаЧсть               0
# 9  Ваангард по чМосквоСркяа иоблаЧсть               0
#
#                    candidate_names  candidate_id
# 0   Авангард по Московская область             1
# 1   Авангард по Московская область             1
# 2   Авангард по Московская область             1
# 3   Авангард по Московская область             1
# 4   Авангард по Московская область             1
# 5   Авангард по Московская область             1
# 6  Пахомовой по Московская область           129
# 7   Авангард по Московская область             1
# 8   Авангард по Московская область             1
# 9   Авангард по Московская область             1

# %%
((df.united == df.candidate_names).sum()/df.shape[0])*100
# Out:
# 76.5625

# %% [markdown]
# 76% - результат, достаточно далекий от идеала. Пробуем еще одну модель у sentence-transformers:

# %%
model = SentenceTransformer('sentence-transformers/distiluse-base-multilingual-cased-v1')
corpus = model.encode(df_clean.united.values)
query = model.encode(df.aug.values)

# %%
search_res = semantic_search(query, corpus, top_k=1)

# %%
df['candidates_ind'] = [x[0]['corpus_id'] for x in search_res]
df['candidate_names'] = df.candidates_ind.transform(lambda x: df_clean.united.values[x])
df['candidate_id'] = df.candidates_ind.transform(lambda x: df_clean.school_id.values[x])
df.head(10)
# Out:
#    school_id                          united  \
# 0          1  Авангард по Московская область
# 1          1  Авангард по Московская область
# 2          1  Авангард по Московская область
# 3          1  Авангард по Московская область
# 4          1  Авангард по Московская область
# 5          1  Авангард по Московская область
# 6          1  Авангард по Московская область
# 7          1  Авангард по Московская область
# 8          1  Авангард по Московская область
# 9          1  Авангард по Московская область
#
#                                   aug  candidates_ind  \
# 0  АовангОард по ЙМоскьовкяса обалсть               1
# 1  АонваоГард по ЙМоскьовская боалсьт               1
# 2  АовангОард по МЙокьсовская облсьат               1
# 3  АоавнгОдар по ЙМоскьовская обалсть             118
# 4  Авагандр по ХМоскобвская обласатНь             118
# 5  Авангард по МХоскбовскяа олбааснТь               1
# 6  Аавгнадр по ХМоскобвская боалсатНь             118
# 7  Ваанград по ХМоскобвская олбаастЬн              29
# 8  Аавгнадр по чМосковРская иболаЧсть              92
# 9  Ваангард по чМосквоСркяа иоблаЧсть              29
#
#                  candidate_names  candidate_id
# 0  Авангард по Ямало-Ненецкий АО             2
# 1  Авангард по Ямало-Ненецкий АО             2
# 2  Авангард по Ямало-Ненецкий АО             2
# 3          Олимпиец по ХМАО-Югра           123
# 4          Олимпиец по ХМАО-Югра           123
# 5  Авангард по Ямало-Ненецкий АО             2
# 6          Олимпиец по ХМАО-Югра           123
# 7  Витязь по Вологодская область            31
# 8                МАФКК по Москва            96
# 9  Витязь по Вологодская область            31

# %%
((df.united == df.candidate_names).sum()/df.shape[0])*100
# Out:
# 59.65711805555556

# %% [markdown]
# Метрика пошла вниз. Надо посмотреть, как отработает Tf-Idf Vectorizer вместе с опорными векторами или регрессией:

# %%
features = df['united']
target = df['school_id']

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from nltk.corpus import stopwords 
STOP_WORDS = list(stopwords.words('english'))
# векторизируем наш текст:
vect = TfidfVectorizer(stop_words=list(STOP_WORDS))
tfidf_train = vect.fit_transform(features)
print(tfidf_train.shape)
# Out:
# (4608, 364)

# %%
from sklearn.metrics import accuracy_score, make_scorer
from sklearn.svm import LinearSVC
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split, RandomizedSearchCV

score = make_scorer(accuracy_score, greater_is_better = True)

def return_best_model(model, params, features, target):
    
    pipeline = Pipeline(steps=[
        ('vect', TfidfVectorizer(stop_words=STOP_WORDS)), 
        ('clf', model)])
    
    search = RandomizedSearchCV(pipeline, param_distributions = params, cv=3, 
                                    scoring = score, random_state=12345, verbose=4)
    print('start search')
    search.fit(features, target)
    print(f'best params: {search.best_params_}')
    print(f'best score: {search.best_score_}')
    search.best_estimator_.fit(features, target)
    predictions = search.best_estimator_.predict(features)        
    return search

# %%
model = LinearSVC()
params_lsvc = {'clf__C': [0.1, 1, 10],
               'clf__max_iter': [100, 1000, 2000],
               'clf__penalty': ['l1', 'l2'],
               'clf__dual': [True, False]}

search = return_best_model(model, params_lsvc, features, target)
# Out:
# start search
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# [CV 1/3] END clf__C=0.1, clf__dual=True, clf__max_iter=2000, clf__penalty=l2;, score=0.989 total time=   1.2s
# [CV 2/3] END clf__C=0.1, clf__dual=True, clf__max_iter=2000, clf__penalty=l2;, score=0.988 total time=   1.2s
# [CV 3/3] END clf__C=0.1, clf__dual=True, clf__max_iter=2000, clf__penalty=l2;, score=0.990 total time=   1.2s
# [CV 1/3] END clf__C=0.1, clf__dual=True, clf__max_iter=1000, clf__penalty=l1;, score=nan total time=   0.2s
# [CV 2/3] END clf__C=0.1, clf__dual=True, clf__max_iter=1000, clf__penalty=l1;, score=nan total time=   0.2s
# [CV 3/3] END clf__C=0.1, clf__dual=True, clf__max_iter=1000, clf__penalty=l1;, score=nan total time=   0.2s
# [CV 1/3] END clf__C=1, clf__dual=False, clf__max_iter=1000, clf__penalty=l2;, score=0.989 total time=   3.3s
# [CV 2/3] END clf__C=1, clf__dual=False, clf__max_iter=1000, clf__penalty=l2;, score=0.988 total time=   2.5s
# [CV 3/3] END clf__C=1, clf__dual=False, clf__max_iter=1000, clf__penalty=l2;, score=0.990 total time=   2.6s
# [CV 1/3] END clf__C=10, clf__dual=True, clf__max_iter=100, clf__penalty=l2;, score=0.989 total time=   4.5s
# [CV 2/3] END clf__C=10, clf__dual=True, clf__max_iter=100, clf__penalty=l2;, score=0.989 total time=   4.5s
# [CV 3/3] END clf__C=10, clf__dual=True, clf__max_iter=100, clf__penalty=l2;, score=0.990 total time=   4.5s
# [CV 1/3] END clf__C=10, clf__dual=True, clf__max_iter=2000, clf__penalty=l1;, score=nan total time=   0.0s
# [CV 2/3] END clf__C=10, clf__dual=True, clf__max_iter=2000, clf__penalty=l1;, score=nan total time=   0.0s
# [CV 3/3] END clf__C=10, clf__dual=True, clf__max_iter=2000, clf__penalty=l1;, score=nan total time=   0.0s
# [CV 1/3] END clf__C=0.1, clf__dual=True, clf__max_iter=1000, clf__penalty=l2;, score=0.989 total time=   0.9s
# [CV 2/3] END clf__C=0.1, clf__dual=True, clf__max_iter=1000, clf__penalty=l2;, score=0.988 total time=   0.9s
# [CV 3/3] END clf__C=0.1, clf__dual=True, clf__max_iter=1000, clf__penalty=l2;, score=0.990 total time=   1.0s
# [CV 1/3] END clf__C=0.1, clf__dual=True, clf__max_iter=100, clf__penalty=l1;, score=nan total time=   0.0s
# [CV 2/3] END clf__C=0.1, clf__dual=True, clf__max_iter=100, clf__penalty=l1;, score=nan total time=   0.0s
# [CV 3/3] END clf__C=0.1, clf__dual=True, clf__max_iter=100, clf__penalty=l1;, score=nan total time=   0.0s
# [CV 1/3] END clf__C=0.1, clf__dual=True, clf__max_iter=2000, clf__penalty=l1;, score=nan total time=   0.0s
# [CV 2/3] END clf__C=0.1, clf__dual=True, clf__max_iter=2000, clf__penalty=l1;, score=nan total time=   0.0s
# [CV 3/3] END clf__C=0.1, clf__dual=True, clf__max_iter=2000, clf__penalty=l1;, score=nan total time=   0.0s
# [CV 1/3] END clf__C=10, clf__dual=True, clf__max_iter=100, clf__penalty=l1;, score=nan total time=   0.0s
# [CV 2/3] END clf__C=10, clf__dual=True, clf__max_iter=100, clf__penalty=l1;, score=nan total time=   0.0s
# [CV 3/3] END clf__C=10, clf__dual=True, clf__max_iter=100, clf__penalty=l1;, score=nan total time=   0.0s
# [CV 1/3] END clf__C=10, clf__dual=False, clf__max_iter=100, clf__penalty=l2;, score=0.989 total time=   6.2s
# [CV 2/3] END clf__C=10, clf__dual=False, clf__max_iter=100, clf__penalty=l2;, score=0.988 total time=   6.2s
# [CV 3/3] END clf__C=10, clf__dual=False, clf__max_iter=100, clf__penalty=l2;, score=0.990 total time=   6.2s
# best params: {'clf__penalty': 'l2', 'clf__max_iter': 100, 'clf__dual': True, 'clf__C': 10}
# best score: 0.9893663194444443

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
params_lr = {
    'clf__penalty': ['l1', 'l2'],
    'clf__C': [0.1, 1, 5, 10, 15],
    'clf__solver':['lbfgs', 'liblinear', 'sag', 'saga']}

search = return_best_model(model, params_lsvc, features, target)
# Out:
# start search
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# [CV 1/3] END clf__C=0.1, clf__dual=True, clf__max_iter=2000, clf__penalty=l2;, score=nan total time=   0.0s
# [CV 2/3] END clf__C=0.1, clf__dual=True, clf__max_iter=2000, clf__penalty=l2;, score=nan total time=   0.0s
# [CV 3/3] END clf__C=0.1, clf__dual=True, clf__max_iter=2000, clf__penalty=l2;, score=nan total time=   0.0s
# [CV 1/3] END clf__C=0.1, clf__dual=True, clf__max_iter=1000, clf__penalty=l1;, score=nan total time=   0.0s
# [CV 2/3] END clf__C=0.1, clf__dual=True, clf__max_iter=1000, clf__penalty=l1;, score=nan total time=   0.0s
# [CV 3/3] END clf__C=0.1, clf__dual=True, clf__max_iter=1000, clf__penalty=l1;, score=nan total time=   0.0s
# [CV 1/3] END clf__C=1, clf__dual=False, clf__max_iter=1000, clf__penalty=l2;, score=0.989 total time=   3.6s
# [CV 2/3] END clf__C=1, clf__dual=False, clf__max_iter=1000, clf__penalty=l2;, score=0.988 total time=   3.1s
# [CV 3/3] END clf__C=1, clf__dual=False, clf__max_iter=1000, clf__penalty=l2;, score=0.990 total time=   3.7s
# [CV 1/3] END clf__C=10, clf__dual=True, clf__max_iter=100, clf__penalty=l2;, score=nan total time=   0.0s
# [CV 2/3] END clf__C=10, clf__dual=True, clf__max_iter=100, clf__penalty=l2;, score=nan total time=   0.0s
# [CV 3/3] END clf__C=10, clf__dual=True, clf__max_iter=100, clf__penalty=l2;, score=nan total time=   0.0s
# [CV 1/3] END clf__C=10, clf__dual=True, clf__max_iter=2000, clf__penalty=l1;, score=nan total time=   0.0s
# [CV 2/3] END clf__C=10, clf__dual=True, clf__max_iter=2000, clf__penalty=l1;, score=nan total time=   0.0s
# [CV 3/3] END clf__C=10, clf__dual=True, clf__max_iter=2000, clf__penalty=l1;, score=nan total time=   0.0s
# [CV 1/3] END clf__C=0.1, clf__dual=True, clf__max_iter=1000, clf__penalty=l2;, score=nan total time=   0.0s
# [CV 2/3] END clf__C=0.1, clf__dual=True, clf__max_iter=1000, clf__penalty=l2;, score=nan total time=   0.0s
# [CV 3/3] END clf__C=0.1, clf__dual=True, clf__max_iter=1000, clf__penalty=l2;, score=nan total time=   0.0s
# [CV 1/3] END clf__C=0.1, clf__dual=True, clf__max_iter=100, clf__penalty=l1;, score=nan total time=   0.0s
# [CV 2/3] END clf__C=0.1, clf__dual=True, clf__max_iter=100, clf__penalty=l1;, score=nan total time=   0.0s
# [CV 3/3] END clf__C=0.1, clf__dual=True, clf__max_iter=100, clf__penalty=l1;, score=nan total time=   0.0s
# [CV 1/3] END clf__C=0.1, clf__dual=True, clf__max_iter=2000, clf__penalty=l1;, score=nan total time=   0.0s
# [CV 2/3] END clf__C=0.1, clf__dual=True, clf__max_iter=2000, clf__penalty=l1;, score=nan total time=   0.0s
# [CV 3/3] END clf__C=0.1, clf__dual=True, clf__max_iter=2000, clf__penalty=l1;, score=nan total time=   0.0s
# [CV 1/3] END clf__C=10, clf__dual=True, clf__max_iter=100, clf__penalty=l1;, score=nan total time=   0.0s
# [CV 2/3] END clf__C=10, clf__dual=True, clf__max_iter=100, clf__penalty=l1;, score=nan total time=   0.0s
# [CV 3/3] END clf__C=10, clf__dual=True, clf__max_iter=100, clf__penalty=l1;, score=nan total time=   0.0s
# [CV 1/3] END clf__C=10, clf__dual=False, clf__max_iter=100, clf__penalty=l2;, score=0.989 total time=   6.7s
# [CV 2/3] END clf__C=10, clf__dual=False, clf__max_iter=100, clf__penalty=l2;, score=0.988 total time=   7.1s
# [CV 3/3] END clf__C=10, clf__dual=False, clf__max_iter=100, clf__penalty=l2;, score=0.990 total time=   6.6s
# best params: {'clf__penalty': 'l2', 'clf__max_iter': 1000, 'clf__dual': False, 'clf__C': 1}
# best score: 0.9891493055555555

# %% [markdown]
# Будем использовать опорные вектора. Теперь, опробуем модели на сырых данных:

# %%
model = SentenceTransformer('sentence-transformers/LaBSE')

# %%
corpus = model.encode(df_clean.united.values)

# %%
query = model.encode(df_rough.name.values)

# %%
search_res = semantic_search(query, corpus, top_k=1)

# %%
data = df_rough.copy()

# %%
data['candidates_ind'] = [x[0]['corpus_id'] for x in search_res]
data['candidates_names'] = data.candidates_ind.transform(lambda x: df_clean.united.values[x])
data['candidate_id'] = data.candidates_ind.transform(lambda x: df_clean.school_id.values[x])
data.head(25)
# Out:
#     school_id                                               name  \
# 0        1836                                       ООО "Триумф"
# 1        1836                                Москва, СК "Триумф"
# 2         610                             СШОР "Надежда Губернии
# 3         610  Саратовская область, ГБУСО "СШОР "Надежда Губе...
# 4         609                                     "СШ "Гвоздика"
# 5         304                                          СШ по ЗВС
# 6         304                      Пензенская область, СШ по ЗВС
# 7         304  Пензенская область, МБУ ДО "СШ по зимним видам...
# 8         303                                     ООО "СетПоинт"
# 9         303                             Москва, ООО "Сетпоинт"
# 10        302                                              СШ №2
# 11        301                              МБУ "ЦФКиС г. Лобня"
# 12        300                 Рязанская область, ХК "Рязань-ВДВ"
# 13        300                            ГАУ РО "ХК "Рязань-ВДВ"
# 14        299                                     РФСОО "ФФККРК"
# 15        298                                 АНО СК "ЮНАРМЕЙЦЫ"
# 16        298            Севастополь, СК "ЮНАРМЕЙЦЫ Севастополя"
# 17        297                               ЧУДО ДЮСОШ "СИЯНИЕ"
# 18        296                        МБОУ ДО СШ №8 "Локомотив",
# 19        296    МБОУ ДО СШ №8 "Локомотив", Свердловская область
# 20        295                                       ГУ ТО ОКСШОР
# 21        294                   ГБУ "МосСпортОбъект" ЛЦ "Звезда"
# 22        294           Москва, ГБУ "МосСпортОбъект" ЛЦ "Звезда"
# 23        293                         АНО Лига фигурного катания
# 24        293                 Москва, АНО Лига фигурного катания
#
#     candidates_ind                                   candidates_names  \
# 0              287                             ООО "Триумф" по Москва
# 1              287                             ООО "Триумф" по Москва
# 2              285      СШОР "Надежда Губернии по Саратовская область
# 3              285      СШОР "Надежда Губернии по Саратовская область
# 4              284            "СШ "Гвоздика" по Удмуртская республика
# 5              166                                    СШ по ХМАО-Югра
# 6              282                    СШ по ЗВС по Пензенская область
# 7              282                    СШ по ЗВС по Пензенская область
# 8              281                           ООО "СетПоинт" по Москва
# 9              281                           ООО "СетПоинт" по Москва
# 10             197                                   СШОР 2 по Москва
# 11             279        МБУ "ЦФКиС г. Лобня"  по Московская область
# 12             278       ГАУ РО "ХК "Рязань-ВДВ" по Рязанская область
# 13             278       ГАУ РО "ХК "Рязань-ВДВ" по Рязанская область
# 14             277                  РФСОО "ФФККРК" по Республика Коми
# 15             276                  АНО СК "ЮНАРМЕЙЦЫ" по Севастополь
# 16             276                  АНО СК "ЮНАРМЕЙЦЫ" по Севастополь
# 17             275        ЧУДО ДЮСОШ "СИЯНИЕ"  по Воронежская область
# 18             274  МБОУ ДО СШ 8 "Локомотив",  по Свердловская обл...
# 19             274  МБОУ ДО СШ 8 "Локомотив",  по Свердловская обл...
# 20             273                   ГУ ТО ОКСШОР по Тульская область
# 21             272         ГБУ "МосСпортОбъект" ЛЦ "Звезда" по Москва
# 22             272         ГБУ "МосСпортОбъект" ЛЦ "Звезда" по Москва
# 23             271               АНО Лига фигурного катания по Москва
# 24             271               АНО Лига фигурного катания по Москва
#
#     candidate_id
# 0           1836
# 1           1836
# 2            610
# 3            610
# 4            609
# 5            173
# 6            304
# 7            304
# 8            303
# 9            303
# 10           211
# 11           301
# 12           300
# 13           300
# 14           299
# 15           298
# 16           298
# 17           297
# 18           296
# 19           296
# 20           295
# 21           294
# 22           294
# 23           293
# 24           293

# %%
((data.school_id == data.candidate_id).sum()/data.shape[0])*100
# Out:
# 55.53072625698324

# %% [markdown]
# И опорные вектора:

# %%
features = df['united']
target = df['school_id']

features_test = df_rough['name']
target_test = df_rough['school_id']

# векторизируем наш текст:
vect = TfidfVectorizer(stop_words=list(STOP_WORDS))
tfidf_train = vect.fit_transform(features)
tfidf_test = vect.transform(features_test)
model = LinearSVC(C = 10, max_iter = 100, penalty = 'l2', dual = True)

# %%
model = model.fit(tfidf_train, target)

# %%
predictions = model.predict(tfidf_test)

# %%
df_rough['cand_school'] = predictions
df_rough['cand_names'] = [df_clean.set_index('school_id').loc[[x]]['united'].values for x in predictions]

# %%
df_rough
# Out:
#      school_id                                               name  \
# 0         1836                                       ООО "Триумф"
# 1         1836                                Москва, СК "Триумф"
# 2          610                             СШОР "Надежда Губернии
# 3          610  Саратовская область, ГБУСО "СШОР "Надежда Губе...
# 4          609                                     "СШ "Гвоздика"
# ..         ...                                                ...
# 890          3             Республика Татарстан, СШОР ФСО Авиатор
# 891          3             СШОР ФСО Авиатор, Республика Татарстан
# 892          3  Республика Татарстан, МБУ ДО СШОР «ФСО "Авиатор"»
# 893          2                                ЯНАО, СШ "Авангард"
# 894          1                  Московская область, СШ "Авангард"
#
#      cand_school                                       cand_names
# 0           1836                         [ООО "Триумф" по Москва]
# 1           1836                         [ООО "Триумф" по Москва]
# 2            610  [СШОР "Надежда Губернии по Саратовская область]
# 3            610  [СШОР "Надежда Губернии по Саратовская область]
# 4            609        ["СШ "Гвоздика" по Удмуртская республика]
# ..           ...                                              ...
# 890            3                [Авиатор по Республика Татарстан]
# 891            3                [Авиатор по Республика Татарстан]
# 892            3                [Авиатор по Республика Татарстан]
# 893          240                 [ФФКК ЯНАО по Ямало-Ненецкий АО]
# 894            1                 [Авангард по Московская область]
#
# [895 rows x 4 columns]

# %%
accuracy_score(target_test, predictions)*100
# Out:
# 79.44134078212291

# %% [markdown]
# Модель *'из коробки'* работает неплохо, однако пока что лучше всех справились **опорные вектора** - разница составляет практически в 25%.

# %% [markdown]
# #### Этап 4. Результаты, выводы.

# %% [markdown]
# В ходе работы нам были даны две таблицы, содержащие эталонные названия школ и примерное их написание по факту. Стояла задача - подобрать модель и алгоритм, который будет сопоставлять написанные названия школ с эталонными. Обучив нейросеть SentenceTransformers на чистых обработанных данных, получили точность в 76%, что достаточно далеко от идеала. Обучив метод опорных векторов и логистическую регрессию, мы получили результат в разы лучше - практически 99% совпадений.
